# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re 
import seaborn as sns
# %matplotlib inline

# %%
#We'll start from 1990/1991 Season to 2016/2017
#Pull all player data and clean
full_player_data = pd.DataFrame()
for i in range(1991,2018):
    print(i)
    url = 'https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'.format(i)
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    column_headers = [th.getText() for th in
                  soup.findAll('tr', limit=1)[0].findAll('th')[1:]]

    data_rows = soup.findAll('tr')[1:]
    player_data = [[td.getText() for td in data_rows[i].findAll('td')]
            for i in range(len(data_rows))]
    player_data_02 = []  # create an empty list to hold all the data

    for j in range(len(data_rows)):  # for each table row
        player_row = []  # create an empty list for each pick/player

        # for each table data element from each table row
        for td in data_rows[j].findAll('td'):
            # get the text content and append to the player_row
            player_row.append(td.getText())

        # then append each pick/player to the player_data matrix
        player_data_02.append(player_row)
    df = pd.DataFrame(player_data, columns=column_headers)
    df.fillna(0, inplace=True)
    df.columns = df.columns.str.replace('%', '_Perc')
    df.rename(columns={'PS/G':'PS_per_game'}, inplace=True)
    cols = df.columns.drop(['Player', 'Pos', 'Tm'])
    df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
    df = df[:].fillna(0)
    df.insert(0, 'Season', '{}'.format(str(i-1) + "-" + str(i)[-2:]))
#     print('Season', '{}'.format(str(i) + "-" + str(i+1)[-2:]))
    full_player_data = full_player_data.append(df, ignore_index=True)
# Out:
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017

# %%
# full_player_data.to_csv('Player_Data.csv')
full_player_data = pd.read_csv('Player_Data.csv', index_col=0)
full_player_data = full_player_data[full_player_data['Player']!='0']
full_player_data['Player'] = full_player_data['Player'].map(lambda x: re.sub(r'\*', '', x)).astype(str)
full_player_data['Season'] = full_player_data['Season'].map(lambda x: re.sub(r'\*', '', x)).astype(str)
full_player_data['Tm'] = full_player_data['Tm'].map(lambda x: re.sub(r'\*', '', x)).astype(str)
full_player_data['Season'] = full_player_data['Season'].map(lambda x: re.sub('-', '', x)[0:4]).astype(int)
# print(full_player_data.dtypes)
full_player_data.head()
# Out:
#    Season              Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 0    1990      Alaa Abdelnaby  PF   22  POR  43   0   6.7  1.3   2.7
# 1    1990  Mahmoud Abdul-Rauf  PG   21  DEN  67  19  22.5  6.2  15.1
# 2    1990          Mark Acres   C   28  ORL  68   0  19.3  1.6   3.1
# 3    1990       Michael Adams  PG   28  DEN  66  66  35.5  8.5  21.5
# 4    1990        Mark Aguirre  SF   31  DET  78  13  25.7  5.4  11.7
#
#       ...       FT_Perc  ORB  DRB  TRB   AST  STL  BLK  TOV   PF  PS_per_game
# 0     ...         0.568  0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9          3.1
# 1     ...         0.857  0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2         14.1
# 2     ...         0.653  2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2          4.2
# 3     ...         0.879  0.9  3.0  3.9  10.5  2.2  0.1  3.6  2.5         26.5
# 4     ...         0.757  1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7         14.2
#
# [5 rows x 30 columns]

# %%
#Need to now get the list of Most Improved Players from somewhere, and link to the full dataset
url = 'https://en.wikipedia.org/wiki/NBA_Most_Improved_Player_Award'
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')
table = soup.find("table", { "class" : "wikitable plainrowheaders sortable" })

# %%
full_award_data = pd.DataFrame()
row = table.findAll("tr")[7]
cell = row.findAll("td")[0]
year = str(cell.find(text=True))
namerow = row.findAll("th")[0]
name = namerow.find("a").find(text=True)
# a = {'Player' : pd.series(name), 'Sess'
# df = pd.DataFrame(columns=['Player', 'Season'])


full_player_data2 = full_player_data.copy()
players = []
seasons = []
for i in range(7,len(range(1991,2018))+6):
    row = table.findAll("tr")[i]
    cell = row.findAll("td")[0]
    year = int(str(cell.find(text=True))[0:4])
    namerow = row.findAll("th")[0]
    name = str(namerow.find("a").find(text=True))
#     print(type(name), type(year))
#     print(type(full_player_data['Player']))
    print(name)
    if name == 'Chris Jackson':
        name = 'Mahmoud Abdul-Rauf'
    elif name == 'Gheorghe Mureșan':
        name = 'Gheorghe Muresan'
    elif name == 'Hedo Türkoğlu':
        name = 'Hedo Turkoglu'
    elif name == 'C. J. McCollum':
        name = 'C.J. McCollum'
    for j in range(0,len(full_player_data.index)-1):
        if (year == full_player_data['Season'].iloc[j]) and (name == full_player_data['Player'].iloc[j]):
#             print(full_player_data['Season'].iloc[j], full_player_data['Player'].iloc[j])    
            players.append(name)
            seasons.append(year)
#             print(year, name)
# print('end')
# print(full_player_data[full_player_data['MIP']==1])
MIP_awards = pd.DataFrame({'Player' : players, 'Season' : seasons, 'MIPFlag' : 1})
# Out:
# Pervis Ellison
# Chris Jackson
# Don MacLean
# Dana Barros
# Gheorghe Mureșan
# Isaac Austin
# Alan Henderson
# Darrell Armstrong
# Jalen Rose
# Tracy McGrady
# Jermaine O'Neal
# Gilbert Arenas
# Zach Randolph
# Bobby Simmons
# Boris Diaw
# Monta Ellis
# Hedo Türkoğlu
# Danny Granger
# Aaron Brooks
# Kevin Love
# Ryan Anderson
# Paul George
# Goran Dragić
# Jimmy Butler
# C. J. McCollum
# Giannis Antetokounmpo

# %%
#merge the dataframes
full_mip_data = pd.merge(full_player_data, MIP_awards, on=['Player', 'Season'], how='left')

# %%
# Need to clean up players who switch teams mid year - just use their aggregate stats
indexes_to_remove = []
for i in (full_mip_data.Player.unique()):
    df1 = full_mip_data[full_mip_data['Player']==i]
    indexes_to_add = df1[df1.duplicated('Season', keep=False) & (df1['Tm']!='TOT')].index.tolist()
    if len(indexes_to_add)>0:
        for j in range(0,len(indexes_to_add)):
            indexes_to_remove.append(indexes_to_add[j])
    
    
print(max(indexes_to_remove))
#Drop these rows
full_mip_data.drop(full_mip_data.index[indexes_to_remove], inplace=True)
# Out:
# 14641

# %%
#fill null values with zeros
full_mip_data.fillna(value=0, inplace=True)
full_mip_data.head()
# Out:
#    Season              Player Pos  Age   Tm   G  GS    MP   FG   FGA   ...     \
# 0    1990      Alaa Abdelnaby  PF   22  POR  43   0   6.7  1.3   2.7   ...
# 1    1990  Mahmoud Abdul-Rauf  PG   21  DEN  67  19  22.5  6.2  15.1   ...
# 2    1990          Mark Acres   C   28  ORL  68   0  19.3  1.6   3.1   ...
# 3    1990       Michael Adams  PG   28  DEN  66  66  35.5  8.5  21.5   ...
# 4    1990        Mark Aguirre  SF   31  DET  78  13  25.7  5.4  11.7   ...
#
#    ORB  DRB  TRB   AST  STL  BLK  TOV   PF  PS_per_game  MIPFlag
# 0  0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9          3.1      0.0
# 1  0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2         14.1      0.0
# 2  2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2          4.2      0.0
# 3  0.9  3.0  3.9  10.5  2.2  0.1  3.6  2.5         26.5      0.0
# 4  1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7         14.2      0.0
#
# [5 rows x 31 columns]

# %%
# now need to calculate the players seasons stats as a difference between the current year and the past year. To view stat improvement.
columns_needed = ['G','MP', 'FG', 'FG_Perc', '3P_Perc', '2P', 'eFG_Perc',
 'FT', 'FT_Perc', 'TRB', 'AST', 'STL', 'BLK', 'PS_per_game']

full_mip_data_diff = pd.DataFrame()
for i in full_mip_data.Player.unique():
    player_subset = full_mip_data[full_mip_data['Player']==i]
    diffvalues = player_subset.sort_values(['Player','Season']).groupby('Player')[columns_needed].diff()
    player_full = pd.concat([player_subset[['Player', 'Season','MIPFlag', 'Age']], diffvalues], axis=1)
    full_mip_data_diff = full_mip_data_diff.append(player_full)
#Create new variable called year number for the players nba career
full_mip_data_diff['year_no'] = full_mip_data_diff.groupby('Player')['Age'].rank()
full_mip_data_diff.dropna(inplace=True)

# %%
#Scale the features
from sklearn.preprocessing import StandardScaler
full_mip_data_diff.head()
features = columns_needed.copy()
features.append('year_no')

# %%
scaler = StandardScaler()
scaler.fit(full_mip_data_diff[full_mip_data_diff['Season']!=2016][features])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(full_mip_data_diff[full_mip_data_diff['Season']!=2016][features])
df_feat = pd.DataFrame(scaled_features, columns=features)

# %%
df_feat.head()
# Out:
#           G        MP        FG   FG_Perc   3P_Perc        2P  eFG_Perc  \
# 0  1.267732  1.055943  1.074293  0.274110 -0.007363  1.213910  0.237623
# 1  0.273999  0.721831  0.746366  0.341349 -0.007363  0.847770  0.300590
# 2 -2.458768 -0.736109 -1.139218 -0.857743 -0.007363 -1.257537 -0.822312
# 3  1.806004 -0.356437  0.418438  0.901672 -0.007363  0.481629  0.825310
# 4  0.688054 -0.462745 -1.385163  0.150839  0.497726 -1.623678  0.195646
#
#          FT   FT_Perc       TRB       AST       STL       BLK  PS_per_game  \
# 0  0.725072  1.093186  1.194413  0.162869  1.067073 -0.293421     1.016093
# 1  0.216136  0.075211  0.630697  0.050663 -0.262615  0.445202     0.581696
# 2  0.088903 -0.649450 -0.637665 -0.173747 -0.262615 -0.293421    -0.783553
# 3 -0.928968 -0.361886 -0.919523  0.050663  0.402229  0.075890     0.023185
# 4 -0.038331  0.109718 -0.214877 -0.734774 -0.927458 -0.293421    -1.093837
#
#     year_no
# 0 -1.111814
# 1 -0.822083
# 2 -0.532353
# 3 -0.242623
# 4 -1.111814

# %%
#Use Random Forest and train on every year except most recent.
from sklearn.ensemble import RandomForestClassifier

# %%
#Scale the train features
from sklearn.preprocessing import StandardScaler
full_mip_data_diff.head()
features = columns_needed.copy()
features.append('year_no')
scaler_train = StandardScaler()
scaler_train.fit(full_mip_data_diff[full_mip_data_diff['Season']!=2016][features])
scaled_features_train = scaler_train.transform(full_mip_data_diff[full_mip_data_diff['Season']!=2016][features])
df_feat_train = pd.DataFrame(scaled_features_train, columns=features)
#Scale the test features
scaler_test = StandardScaler()
scaler_test.fit(full_mip_data_diff[full_mip_data_diff['Season']==2016][features])
scaled_features_test = scaler_test.transform(full_mip_data_diff[full_mip_data_diff['Season']==2016][features])
df_feat_test = pd.DataFrame(scaled_features_test, columns=features)

# %%
features2 = features.copy()
features2.append('Season')

y = full_mip_data_diff[['Season','MIPFlag']]
X_train = df_feat_train
y_train = y[y['Season']!=2016].drop('Season', axis=1)
X_test = df_feat_test
y_test = y[y['Season']==2016].drop('Season', axis=1)

# %%
X_test.head()
# Out:
#           G        MP        FG   FG_Perc   3P_Perc        2P  eFG_Perc  \
# 0  1.452930  1.933169  2.719010  0.321591  0.174208  2.265605  0.171079
# 1  0.139969  0.683203  0.120068 -0.134412  0.033126 -0.091703 -0.053026
# 2  0.139969  0.595178  0.466594  0.032418  1.354847  0.523247  0.130332
# 3 -2.767301 -0.883655 -0.659615 -0.278998 -1.073258 -0.296686 -0.511423
# 4 -0.516511  1.493040  0.466594 -0.367974  2.238469  0.010789  0.354437
#
#          FT   FT_Perc       TRB       AST       STL       BLK  PS_per_game  \
# 0  1.574976 -0.683471  0.929924  1.451505  1.217341  0.447299     2.689637
# 1  0.289581  0.209444 -0.177893  0.669775  0.483072 -0.217402     0.171481
# 2  0.575224  0.306267  0.771665  0.893126  1.584475  0.779649     0.535951
# 3 -0.138884 -0.360731  0.138626 -0.893686 -0.251197  2.441402    -0.656860
# 4  1.146511 -0.769535  0.138626  0.223072  1.584475  0.114948     0.867287
#
#     year_no
# 0 -0.544629
# 1  0.332114
# 2 -1.170874
# 3 -0.795127
# 4  1.208857

# %%
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train, y_train['MIPFlag'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
predictions = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[398   0]
#  [  1   0]]

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00       398
#         1.0       0.00      0.00      0.00         1
#
# avg / total       0.99      1.00      1.00       399
# C:\Users\miah.stewart\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
##Try KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train['MIPFlag'])
pred = knn.predict(X_test)
pred_prob = knn.predict_proba(X_test)
print(confusion_matrix(y_test['MIPFlag'], pred))
print(classification_report(y_test['MIPFlag'], pred))
# Out:
# [[397   1]
#  [  1   0]]
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00       398
#         1.0       0.00      0.00      0.00         1
#
# avg / total       0.99      0.99      0.99       399

# %%
error_rate = []
for i in range(1,10):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train['MIPFlag'])
    pred_i= knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test['MIPFlag']))

# %%
plt.figure(figsize=(8,10))
plt.plot(range(1,10), error_rate, color='blue', linestyle='dashed')

# %%
compare = full_mip_data_diff[full_mip_data_diff['Season']==2016].copy()
compare['predictedmip'] = pred

# %%
compare[compare['predictedmip']==1]
# Out:
#                 Player  Season  MIPFlag  Age    G    MP   FG  FG_Perc  \
# 14542  Dennis Schroder    2016      0.0   23 -1.0  11.2  2.8     0.03
#
#        3P_Perc   2P  eFG_Perc   FT  FT_Perc  TRB  AST  STL  BLK  PS_per_game  \
# 14542    0.018  2.5     0.022  1.0    0.064  0.5  1.9  0.0  0.1          6.9
#
#        year_no  predictedmip
# 14542      4.0           1.0

# %%
compare[compare['Player']=='Giannis Antetokounmpo']
# Out:
#                       Player  Season  MIPFlag  Age    G   MP   FG  FG_Perc  \
# 14082  Giannis Antetokounmpo    2016      1.0   22  0.0  0.3  1.8    0.015
#
#        3P_Perc   2P  eFG_Perc   FT  FT_Perc  TRB  AST  STL  BLK  PS_per_game  \
# 14082    0.015  1.5     0.021  2.2    0.046  1.1  1.1  0.4  0.5          6.0
#
#        year_no  predictedmip
# 14082      4.0           0.0

# %%
compare[compare['Player']=='Devin Booker']
# Out:
#              Player  Season  MIPFlag  Age    G   MP   FG  FG_Perc  3P_Perc  \
# 14125  Devin Booker    2016      0.0   20  2.0  7.3  3.0      0.0     0.02
#
#         2P  eFG_Perc   FT  FT_Perc  TRB  AST  STL  BLK  PS_per_game  \
# 14125  2.4    -0.005  1.9   -0.008  0.7  0.8  0.3  0.0          8.3
#
#        predictedmip
# 14125           0.0
