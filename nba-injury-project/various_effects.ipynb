# %%
import pandas as pd
import datetime as dt
from datetime import datetime
import seaborn as sns

# %%
#Read in player logs
hist_player_log_full = pd.read_csv('hist_player_log.csv')
hist_player_log_full['GAME_DATE'] = hist_player_log_full['GAME_DATE'].apply(lambda x: datetime.strptime(x, '%b %d, %Y'))
#Read in player injury history
full_injury_data_final = pd.read_csv('full_injury_data_final.csv', parse_dates=['Date'])
#Read in player info
hist_player_info = pd.read_csv('hist_player_info.csv', parse_dates=['BIRTHDATE'])

# %%
#Build a dataset for effect analysis.
full_injury_data_final.head()
# Out:
#         Date        Team Acquired                    Relinquished  \
# 0 2014-05-03    Warriors                             Andrew Bogut
# 1 2014-05-04   Mavericks                                Gal Mekel
# 2 2014-05-06       76ers                  Michael Carter-Williams
# 3 2014-05-13   Cavaliers                          Anthony Bennett
# 4 2014-05-14     Blazers           Maurice Williams / Mo Williams
#
#                                                Notes  \
# 0                          fractured right rib (DNP)
# 1                                  knee injury (DNP)
# 2  surgery on right shoulder to repair torn labru...
# 3  surgery for removal of tonsils and adnoids (ou...
# 4                               strained groin (DNP)
#
#                     full_name_raw           full_name_main full_name_alt  \
# 0                    Andrew Bogut             Andrew Bogut           NaN
# 1                       Gal Mekel                Gal Mekel           NaN
# ...

# %%
hist_player_log_full[['full_name', 'GAME_DATE', 'MIN']].head()
# Out:
#       full_name  GAME_DATE  MIN
# 0  Alex Abrines 2018-12-23   27
# 1  Alex Abrines 2018-12-22   16
# 2  Alex Abrines 2018-12-19   23
# 3  Alex Abrines 2018-12-17   14
# 4  Alex Abrines 2018-12-15   20

# %%
hist_player_log_full.head()
# Out:
#    SEASON_ID  Player_ID   Game_ID  GAME_DATE      MATCHUP WL  MIN  FGM  FGA  \
# 0      22018     203518  21800493 2018-12-23  OKC vs. MIN  L   27    2    6
# 1      22018     203518  21800485 2018-12-22    OKC @ UTA  W   16    2    4
# 2      22018     203518  21800466 2018-12-19    OKC @ SAC  W   23    3    7
# 3      22018     203518  21800447 2018-12-17  OKC vs. CHI  W   14    3    4
# 4      22018     203518  21800434 2018-12-15  OKC vs. LAC  W   20    2    4
#
#    FG_PCT  ...  PTS  PLUS_MINUS  VIDEO_AVAILABLE     full_name  PERSON_ID  \
# 0   0.333  ...    7           1                1  Alex Abrines     203518
# 1   0.500  ...    6          13                1  Alex Abrines     203518
# 2   0.429  ...    9           6                1  Alex Abrines     203518
# 3   0.750  ...    8           4                1  Alex Abrines     203518
# 4   0.500  ...    6           7                1  Alex Abrines     203518
#
#              BIRTHDATE  FROM_YEAR  HEIGHT  WEIGHT  POSITION
# ...
