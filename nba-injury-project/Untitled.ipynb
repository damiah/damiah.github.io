# %%
from nba_api.stats.endpoints import playercareerstats, commonplayerinfo
from nba_api.stats.static import players, teams
import pandas as pd
import time

# %%
#We need a separate call for playoffs and regular season
hist_player_log = playercareerstats.PlayerCareerStats(player_id='202695',
                                                  per_mode36='PerGame').get_data_frames()[0]
hist_player_log.head()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     202695   2011-12        00  1610612759               SAS        21.0
# 1     202695   2012-13        00  1610612759               SAS        22.0
# 2     202695   2013-14        00  1610612759               SAS        23.0
# 3     202695   2014-15        00  1610612759               SAS        24.0
# 4     202695   2015-16        00  1610612759               SAS        25.0
#
#    GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  64  39  24.0  3.1  ...   0.773   1.6   3.5  5.1  1.1  1.3  0.4  0.7  1.4
# 1  58  57  31.2  4.5  ...   0.825   1.1   4.9  6.0  1.6  1.7  0.6  1.1  1.7
# 2  66  65  29.1  5.1  ...   0.802   1.2   5.1  6.2  2.0  1.7  0.8  1.2  1.9
# 3  64  64  31.8  6.2  ...   0.802   1.3   5.9  7.2  2.5  2.3  0.8  1.5  2.0
# 4  72  72  33.0  7.7  ...   0.874   1.3   5.5  6.8  2.6  1.8  1.0  1.5  1.8
#
#     PTS
# 0   7.9
# 1  11.9
# 2  12.8
# 3  16.5
# 4  21.2
# ...

# %%
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
# Out:
# Number of players fetched: 4374
# Number of teams fetched: 30

# %%
#Grab all player-season combos
hist_player_full = pd.DataFrame()
nba_players[0]['full_name']
for i in range(0, len(nba_players)):
    player_id = nba_players[i]['id']
    hist_player = playercareerstats.PlayerCareerStats(player_id=player_id, 
                                                  per_mode36='PerGame'
                                                  ).get_data_frames()[0]
    hist_player['full_name'] = nba_players[i]['full_name']
    hist_player_full = hist_player_full.append(hist_player, ignore_index=True)
    if (i % 100 == 0): 
        time.sleep(0.1)
        print(str(i) + "/" + str(len(nba_players)))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
#Grab player info (date of birth, draft year, etc.)
hist_player_info_full = pd.DataFrame()
for i in hist_player_log_full['Player_ID'].unique():
    player_id = i
    player_info = commonplayerinfo.CommonPlayerInfo(player_id=player_id).get_data_frames()[0][
        ['PERSON_ID', 'BIRTHDATE', 'FROM_YEAR', 'HEIGHT', 'WEIGHT', 'POSITION']]
    player_info['full_name'] = hist_player_log_full['full_name'][hist_player_log_full['Player_ID']==i].unique()[0]
    hist_player_info_full = hist_player_info_full.append(player_info, ignore_index=True)
    time.sleep(0.25)
