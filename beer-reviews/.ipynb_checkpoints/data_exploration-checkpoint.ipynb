# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import random

p=0.1
# df = pandas.read_csv(filename, skiprows=skip)
review_df = pd.read_csv('beer_reviews.csv', skiprows=lambda i: i>0 and random.random() > p)
len(review_df)
# Out:
# 157999

# %%
review_df.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0        1075  Caldera Brewing Company   1273109020             3.5
# 1        1075  Caldera Brewing Company   1312070406             4.0
# 2        1075  Caldera Brewing Company   1311558510             3.0
# 3        1075  Caldera Brewing Company   1297290394             3.5
# 4        1075  Caldera Brewing Company   1286839186             3.5
#
#    review_aroma  review_appearance review_profilename            beer_style  \
# 0           4.0                3.0        RangerClegg  Herbed / Spiced Beer
# 1           4.0                3.0        MrVonzipper             Rauchbier
# 2           4.5                3.0   Beerandraiderfan             Rauchbier
# 3           3.5                4.0            cooch69             Rauchbier
# 4           3.5                4.0         Fatehunter             Rauchbier
#
#    review_palate  review_taste            beer_name  beer_abv  beer_beerid
# 0            3.0           4.0  Caldera Ginger Beer       4.7        52159
# 1            4.0           4.0        Rauch Ür Bock       7.4        58046
# 2            2.0           3.0        Rauch Ür Bock       7.4        58046
# 3            3.5           3.5        Rauch Ür Bock       7.4        58046
# 4            4.0           4.0        Rauch Ür Bock       7.4        58046

# %%
review_df.describe()
# Out:
#           brewery_id   review_time  review_overall   review_aroma  \
# count  157999.000000  1.579990e+05   157999.000000  157999.000000
# mean     3120.478971  1.224273e+09        3.814252       3.734910
# std      5561.583954  7.656731e+07        0.720657       0.698669
# min         1.000000  8.878464e+08        0.000000       1.000000
# 25%       143.000000  1.173231e+09        3.500000       3.500000
# 50%       427.000000  1.239496e+09        4.000000       4.000000
# 75%      2372.000000  1.288838e+09        4.500000       4.000000
# max     27917.000000  1.326277e+09        5.000000       5.000000
#
#        review_appearance  review_palate   review_taste       beer_abv  \
# count      157999.000000  157999.000000  157999.000000  151319.000000
# mean            3.842749       3.742916       3.793347       7.038584
# std             0.614645       0.682067       0.731416       2.311597
# min             0.000000       1.000000       1.000000       0.010000
# 25%             3.500000       3.500000       3.500000       5.200000
# 50%             4.000000       4.000000       4.000000       6.500000
# 75%             4.000000       4.000000       4.500000       8.500000
# max             5.000000       5.000000       5.000000      41.000000
#
#          beer_beerid
# count  157999.000000
# mean    21633.698593
# std     21795.455885
# min         3.000000
# 25%      1713.000000
# 50%     13742.000000
# 75%     39367.000000
# max     77306.000000

# %%
review_df.groupby('beer_style').agg({'beer_beerid' : lambda x: x.nunique()})
# Out:
#                                      beer_beerid
# beer_style
# Altbier                                      190
# American Adjunct Lager                       472
# American Amber / Red Ale                     920
# American Amber / Red Lager                   132
# American Barleywine                          334
# American Black Ale                           174
# American Blonde Ale                          385
# American Brown Ale                           357
# American Dark Wheat Ale                       44
# American Double / Imperial IPA               723
# American Double / Imperial Pilsner            67
# American Double / Imperial Stout             429
# American IPA                                1446
# American Malt Liquor                          82
# American Pale Ale (APA)                     1206
# American Pale Lager                          201
# American Pale Wheat Ale                      376
# American Porter                              816
# American Stout                               449
# American Strong Ale                          323
# American Wild Ale                            308
# Baltic Porter                                147
# Belgian Dark Ale                             136
# Belgian IPA                                  134
# Belgian Pale Ale                             392
# Belgian Strong Dark Ale                      362
# Belgian Strong Pale Ale                      361
# Berliner Weissbier                            41
# Bière de Champagne / Bière Brut               11
# Bière de Garde                                97
# ...                                          ...
# Lambic - Fruit                               147
# Lambic - Unblended                            28
# Light Lager                                  221
# Low Alcohol Beer                              48
# Maibock / Helles Bock                        193
# Milk / Sweet Stout                           162
# Munich Dunkel Lager                          174
# Munich Helles Lager                          180
# Märzen / Oktoberfest                         383
# Oatmeal Stout                                275
# Old Ale                                      150
# Pumpkin Ale                                  162
# Quadrupel (Quad)                              93
# Rauchbier                                     66
# Roggenbier                                    22
# Russian Imperial Stout                       393
# Rye Beer                                     142
# Sahti                                         11
# Saison / Farmhouse Ale                       481
# Schwarzbier                                  166
# Scotch Ale / Wee Heavy                       262
# Scottish Ale                                 199
# Scottish Gruit / Ancient Herbed Ale           36
# Smoked Beer                                   83
# Tripel                                       332
# Vienna Lager                                 116
# Weizenbock                                   111
# Wheatwine                                     68
# Winter Warmer                                255
# Witbier                                      436
#
# [104 rows x 1 columns]

# %%
review_df.groupby('beer_style').agg({'review_profilename' : lambda x: x.nunique()})
# Out:
#                                      review_profilename
# beer_style
# Altbier                                             620
# American Adjunct Lager                             1764
# American Amber / Red Ale                           2463
# American Amber / Red Lager                          784
# American Barleywine                                1570
# American Black Ale                                  874
# American Blonde Ale                                 923
# American Brown Ale                                 1668
# American Dark Wheat Ale                             136
# American Double / Imperial IPA                     3728
# American Double / Imperial Pilsner                  439
# American Double / Imperial Stout                   2565
# American IPA                                       4551
# American Malt Liquor                                318
# American Pale Ale (APA)                            3028
# American Pale Lager                                 664
# American Pale Wheat Ale                            1652
# American Porter                                    2552
# American Stout                                     1637
# American Strong Ale                                1942
# American Wild Ale                                   914
# Baltic Porter                                       852
# Belgian Dark Ale                                    544
# Belgian IPA                                         939
# Belgian Pale Ale                                   1300
# Belgian Strong Dark Ale                            2194
# Belgian Strong Pale Ale                            1881
# Berliner Weissbier                                  307
# Bière de Champagne / Bière Brut                     124
# Bière de Garde                                      498
# ...                                                 ...
# Lambic - Fruit                                      728
# Lambic - Unblended                                  107
# Light Lager                                        1029
# Low Alcohol Beer                                     91
# Maibock / Helles Bock                               830
# Milk / Sweet Stout                                 1060
# Munich Dunkel Lager                                 627
# Munich Helles Lager                                 621
# Märzen / Oktoberfest                               1452
# Oatmeal Stout                                      1362
# Old Ale                                            1092
# Pumpkin Ale                                        1170
# Quadrupel (Quad)                                   1393
# Rauchbier                                           339
# Roggenbier                                           44
# Russian Imperial Stout                             2886
# Rye Beer                                            781
# Sahti                                                90
# Saison / Farmhouse Ale                             1652
# Schwarzbier                                         803
# Scotch Ale / Wee Heavy                             1263
# Scottish Ale                                        699
# Scottish Gruit / Ancient Herbed Ale                 273
# Smoked Beer                                         256
# Tripel                                             1926
# Vienna Lager                                        780
# Weizenbock                                          764
# Wheatwine                                           314
# Winter Warmer                                      1427
# Witbier                                            1882
#
# [104 rows x 1 columns]

# %% [markdown]
# # Objective

# %% [markdown]
# * We want to predict using deep learning what review a user will give a beer that they haven't reviewed yet.
# * Then we can extract the weight embeddings of each beer and map to create recommendation engine.

# %%
from fastai.collab import *

# %%
#From fast.ai

class EmbeddingDotBias(nn.Module):
    "Base dot model for collaborative filtering."
    def __init__(self, n_factors:int, n_users:int, n_items:int, y_range:Tuple[float,float]=None):
        super().__init__()
        self.y_range = y_range
        (self.u_weight, self.i_weight, self.u_bias, self.i_bias) = [embedding(*o) for o in [
            (n_users, n_factors), (n_items, n_factors), (n_users,1), (n_items,1)
        ]]

    def forward(self, users:LongTensor, items:LongTensor) -> Tensor:
        dot = self.u_weight(users)* self.i_weight(items)
        res = dot.sum(1) + self.u_bias(users).squeeze() + self.i_bias(items).squeeze()
        if self.y_range is None: return res
        return torch.sigmoid(res) * (self.y_range[1]-self.y_range[0]) + self.y_range[0]

def collab_learner(data, n_factors=None, use_nn=False, emb_szs=None, layers=None, 
                   ps=None, emb_drop=0., y_range=None, use_bn=True, 
                   bn_final=False, **learn_kwargs)->Learner:
    "Create a Learner for collaborative filtering on `data`."
    emb_szs = data.get_emb_szs(ifnone(emb_szs, {}))
    u,m = data.train_ds.x.classes.values()
    if use_nn: model = EmbeddingNN(emb_szs=emb_szs, layers=layers, ps=ps, emb_drop=emb_drop, y_range=y_range, 
                                   use_bn=use_bn, bn_final=bn_final, **learn_kwargs)
    else:      model = EmbeddingDotBias(n_factors, len(u), len(m), y_range=y_range)
    return CollabLearner(data, model, **learn_kwargs)

class CollabLearner(Learner):
    "`Learner` suitable for collaborative filtering."
    def get_idx(self, arr:Collection, is_item:bool=True):
        "Fetch item or user (based on `is_item`) for all in `arr`. (Set model to `cpu` and no grad.)"
        m = self.model.eval().cpu()
        requires_grad(m,False)
        u_class,i_class = self.data.train_ds.x.classes.values()
        classes = i_class if is_item else u_class
        c2i = {v:k for k,v in enumerate(classes)}
        try: return tensor([c2i[o] for o in arr])
        except Exception as e: 
            print(f"""You're trying to access {'an item' if is_item else 'a user'} that isn't in the training data.
                  If it was in your original data, it may have been split such that it's only in the validation set now.""")

    def bias(self, arr:Collection, is_item:bool=True):
        "Bias for item or user (based on `is_item`) for all in `arr`. (Set model to `cpu` and no grad.)"
        idx = self.get_idx(arr, is_item)
        m = self.model
        layer = m.i_bias if is_item else m.u_bias
        return layer(idx).squeeze()

    def weight(self, arr:Collection, is_item:bool=True):
        "Bias for item or user (based on `is_item`) for all in `arr`. (Set model to `cpu` and no grad.)"
        idx = self.get_idx(arr, is_item)
        m = self.model
        layer = m.i_weight if is_item else m.u_weight
        return layer(idx)

# %%
#Transform each reviewer into an index
users_list = review_df['review_profilename'].unique()
users_index = {user: idx for idx, user in enumerate(users_list)}
#tranform each beer into an index
beers_list = review_df['beer_name'].unique()
beers_index = {beer: idx for idx, beer in enumerate(beers_list)}

# %%
review_df_sub = review_df[['review_profilename', 'beer_beerid', 'review_overall', 'beer_name']]
#Insert reviewer id into dataset
review_df_sub['reviewer_id'] = review_df_sub['review_profilename'].apply(lambda x: users_index[x])
review_df_sub = review_df_sub.drop('review_profilename', axis=1)
review_df_sub.head()
data = CollabDataBunch.from_df(review_df_sub[['reviewer_id', 'beer_beerid', 'review_overall', 'beer_name']]
                               , seed=42,bs=64,num_workers=0, item_name='beer_name')
# Out:
# C:\Users\miah.stewart\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.show_batch()
# Out:
# <table>  <col width='10%'>  <col width='10%'>  <col width='10%'>  <tr>
#     <th>reviewer_id</th>
#     <th>beer_name</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>454</th>
#     <th>Lips Of Faith - Dark Kriek</th>
#     <th>3.5</th>
#   </tr>
#   <tr>
#     <th>1130</th>
#     <th>St. Louis Gueuze Fond Tradition</th>
#     <th>4.0</th>
#   </tr>
#   <tr>
#     <th>10549</th>
#     <th>Obovoid Oak-Aged Oatmeal Stout</th>
#     <th>4.5</th>
#   </tr>
#   <tr>
#     <th>1249</th>
#     <th>Nut Brown Ale</th>
#     <th>4.0</th>
#   </tr>
#   <tr>
#     <th>173</th>
#     <th>River Rat Amber Ale</th>
#     <th>3.5</th>
#   </tr>
# </table>

# %%
y_range = [0,5.5]
learn = collab_learner(data, n_factors=40, y_range=y_range, wd=1e-1)
learn.lr_find()
learn.recorder.plot(skip_end=15)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.601291</td>
#       <td>0.606841</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.545720</td>
#       <td>0.568353</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.519188</td>
#       <td>0.547852</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.388765</td>
#       <td>0.535871</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.236499</td>
#       <td>0.536530</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('dotprod')

# %%
learn.model
# Out:
# EmbeddingDotBias(
#   (u_weight): Embedding(13587, 40)
#   (i_weight): Embedding(19665, 40)
#   (u_bias): Embedding(13587, 1)
#   (i_bias): Embedding(19665, 1)
# )

# %%
g = review_df.groupby('beer_name')['review_overall'].count()
top_beers = g.sort_values(ascending=False).index.values[:1000]
top_beers[:10]
# Out:
# array(['Old Rasputin Russian Imperial Stout', 'India Pale Ale', '90 Minute IPA', 'Sierra Nevada Celebration Ale',
#        'Two Hearted Ale', 'Founders Breakfast Stout', 'Stone Ruination IPA', 'Brooklyn Black Chocolate Stout',
#        'Samuel Adams Boston Lager', 'Sierra Nevada Pale Ale'], dtype=object)

# %%
beer_bias = learn.weight(top_beers, is_item=True)
beer_bias.shape
# Out:
# torch.Size([1000, 40])

# %%
mean_ratings = review_df.groupby('beer_name')['review_overall'].mean()
beer_ratings = [(b, i, mean_ratings.loc[i]) for i,b in zip(top_beers,beer_bias)]

# %%
beer_w = learn.weight(top_beers, is_item=True)
beer_w.shape
# Out:
# torch.Size([1000, 40])

# %%
beer_pca = beer_w.pca(2)
beer_pca.shape
# Out:
# torch.Size([1000, 2])

# %%
fac0,fac1 = beer_pca.t()
beer_comp = [(f, i) for f,i in zip(fac0, top_beers)]

# %%
top_beers
review_df[review_df['beer_name'].isin(top_beers)].groupby('beer_style').agg({'review_profilename' : lambda x: x.nunique()})
# Out:
#                                      review_profilename
# beer_style
# Altbier                                             228
# American Adjunct Lager                              994
# American Amber / Red Ale                           1426
# American Amber / Red Lager                          419
# American Barleywine                                 946
# American Black Ale                                  499
# American Blonde Ale                                 190
# American Brown Ale                                 1040
# American Double / Imperial IPA                     3139
# American Double / Imperial Pilsner                  107
# American Double / Imperial Stout                   2022
# American IPA                                       3650
# American Malt Liquor                                 48
# American Pale Ale (APA)                            1798
# American Pale Lager                                 190
# American Pale Wheat Ale                            1025
# American Porter                                    1663
# American Stout                                     1069
# American Strong Ale                                1477
# American Wild Ale                                   478
# Baltic Porter                                       376
# Belgian Dark Ale                                    232
# Belgian IPA                                         658
# Belgian Pale Ale                                    601
# Belgian Strong Dark Ale                            1675
# Belgian Strong Pale Ale                            1207
# Berliner Weissbier                                  181
# Bière de Champagne / Bière Brut                      52
# Bière de Garde                                      199
# Black & Tan                                         106
# ...                                                 ...
# Japanese Rice Lager                                 108
# Kristalweizen                                       123
# Kölsch                                              182
# Lambic - Fruit                                      352
# Lambic - Unblended                                   43
# Light Lager                                         683
# Maibock / Helles Bock                               393
# Milk / Sweet Stout                                  744
# Munich Dunkel Lager                                 247
# Munich Helles Lager                                 221
# Märzen / Oktoberfest                                986
# Oatmeal Stout                                       880
# Old Ale                                             688
# Pumpkin Ale                                         844
# Quadrupel (Quad)                                   1100
# Rauchbier                                           126
# Russian Imperial Stout                             2474
# Rye Beer                                            370
# Sahti                                                44
# Saison / Farmhouse Ale                              913
# Schwarzbier                                         392
# Scotch Ale / Wee Heavy                              752
# Scottish Ale                                        262
# Scottish Gruit / Ancient Herbed Ale                 161
# Tripel                                             1275
# Vienna Lager                                        484
# Weizenbock                                          401
# Wheatwine                                            89
# Winter Warmer                                       750
# Witbier                                            1257
#
# [92 rows x 1 columns]

# %%
zip(top_beers[idxs], X, Y)

# %%
idxs = np.random.choice(len(top_beers), 50, replace=False)
idxs = list(range(50))
X = fac0[idxs]
Y = fac1[idxs]
plt.figure(figsize=(15,15))
plt.scatter(X, Y)
for i, x, y in zip(top_beers[idxs], X, Y):
    plt.text(x,y,i, color=np.random.rand(3)*0.7, fontsize=10)
plt.show()

# %%
idxs = np.random.choice(len(top_beers), 50, replace=False)
idxs = list(range(50))
X = fac0[idxs]
Y = fac1[idxs]
plt.figure(figsize=(15,15))
plt.scatter(X, Y)
for i, x, y in zip(, X, Y):
    plt.text(x,y,i, color=np.random.rand(3)*0.7, fontsize=10)
plt.show()

# %%
beer_and_style = []

# Iterate through each book
for beer in top_beers:
    # Iterate through the links in the book
    beer_and_style.extend((beer, beers_lookup[beers_lookup['beer_name']==beer]['beer_style']))
beer_and_style
# Out:
# ['Old Rasputin Russian Imperial Stout', 125480    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'India Pale Ale', 6745      English India Pale Ale (IPA)
#  10175     English India Pale Ale (IPA)
#  20903                     American IPA
#  21020                     American IPA
#  21072                     American IPA
#  21118                     American IPA
#  24239                     American IPA
#  27821                     American IPA
#  34456     English India Pale Ale (IPA)
#  37825                     American IPA
#  39544                     American IPA
#  43941                     American IPA
#  46001                     American IPA
#  47476                     American IPA
#  52777     English India Pale Ale (IPA)
#  59065     English India Pale Ale (IPA)
#  71206                     American IPA
#  73132                     American IPA
#  73821                     American IPA
#  74727                     American IPA
#  75842                     American IPA
#  79859     English India Pale Ale (IPA)
#  81425                     American IPA
#  83941     English India Pale Ale (IPA)
#  89506                     American IPA
#  90542     English India Pale Ale (IPA)
#  94121     English India Pale Ale (IPA)
#  99675                     American IPA
#  103697                    American IPA
#  105862    English India Pale Ale (IPA)
#  107482                    American IPA
#  119447                    American IPA
#  122563                    American IPA
#  122787    English India Pale Ale (IPA)
#  124036                    American IPA
#  124521                    American IPA
#  128472    English India Pale Ale (IPA)
#  130512    English India Pale Ale (IPA)
#  130665                    American IPA
#  133943                    American IPA
#  134030    English India Pale Ale (IPA)
#  134642                    American IPA
#  137593                    American IPA
#  138096                    American IPA
#  138114                    American IPA
#  139821                    American IPA
#  139828                    American IPA
#  139900                    American IPA
#  142005                    American IPA
#  142226    English India Pale Ale (IPA)
#  142664                    American IPA
#  142892                    American IPA
#  146477    English India Pale Ale (IPA)
#  146782    English India Pale Ale (IPA)
#  146801                    American IPA
#  150650                    American IPA
#  156072    English India Pale Ale (IPA)
#  156788    English India Pale Ale (IPA)
#  157992                    American IPA
#  Name: beer_style, dtype: object, '90 Minute IPA', 116347    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Sierra Nevada Celebration Ale', 7522    American IPA
#  Name: beer_style, dtype: object, 'Two Hearted Ale', 92467    American IPA
#  Name: beer_style, dtype: object, 'Founders Breakfast Stout', 975    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Stone Ruination IPA', 86439    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Brooklyn Black Chocolate Stout', 151964    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Samuel Adams Boston Lager', 27619    Vienna Lager
#  Name: beer_style, dtype: object, 'Sierra Nevada Pale Ale', 7845    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'La Fin Du Monde', 35715    Tripel
#  Name: beer_style, dtype: object, 'Duvel', 96250    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Stone IPA (India Pale Ale)', 86059    American IPA
#  Name: beer_style, dtype: object, 'Arrogant Bastard Ale', 84682    American Strong Ale
#  Name: beer_style, dtype: object, 'St. Bernardus Abt 12', 149081    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'Sierra Nevada Bigfoot Barleywine Style Ale', 7552    American Barleywine
#  Name: beer_style, dtype: object, '60 Minute IPA', 115988    American IPA
#  Name: beer_style, dtype: object, "Bell's Hopslam Ale", 92426    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Pliny The Elder', 112447    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Imperial Stout', 21119               Russian Imperial Stout
#  37788               Russian Imperial Stout
#  45520     American Double / Imperial Stout
#  49078               Russian Imperial Stout
#  55252     American Double / Imperial Stout
#  58135     American Double / Imperial Stout
#  65673               Russian Imperial Stout
#  68044     American Double / Imperial Stout
#  70050     American Double / Imperial Stout
#  70792     American Double / Imperial Stout
#  72804     American Double / Imperial Stout
#  73565               Russian Imperial Stout
#  81422               Russian Imperial Stout
#  82157     American Double / Imperial Stout
#  90539               Russian Imperial Stout
#  90816     American Double / Imperial Stout
#  104950              Russian Imperial Stout
#  107532    American Double / Imperial Stout
#  108861              Russian Imperial Stout
#  112508              Russian Imperial Stout
#  119515              Russian Imperial Stout
#  122175              Russian Imperial Stout
#  128156              Russian Imperial Stout
#  128216              Russian Imperial Stout
#  128324              Russian Imperial Stout
#  130583    American Double / Imperial Stout
#  133849              Russian Imperial Stout
#  137962    American Double / Imperial Stout
#  138425    American Double / Imperial Stout
#  146458              Russian Imperial Stout
#  147631    American Double / Imperial Stout
#  148873    American Double / Imperial Stout
#  156115              Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Storm King Stout', 153962    Russian Imperial Stout
#  Name: beer_style, dtype: object, "Young's Double Chocolate Stout", 139709    Milk / Sweet Stout
#  Name: beer_style, dtype: object, 'Stone Imperial Russian Stout', 86833    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Guinness Draught', 123397    Irish Dry Stout
#  Name: beer_style, dtype: object, 'Chocolate Stout', 35910     American Stout
#  50371     American Stout
#  81241     American Stout
#  106850    American Stout
#  128235    American Stout
#  Name: beer_style, dtype: object, 'Trappistes Rochefort 10', 32380    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'HopDevil Ale', 151409    American IPA
#  Name: beer_style, dtype: object, 'Pale Ale', 657       American Pale Ale (APA)
#  1228      American Pale Ale (APA)
#  4106      American Pale Ale (APA)
#  6767      American Pale Ale (APA)
#  11924            English Pale Ale
#  12629     American Pale Ale (APA)
#  17408            English Pale Ale
#  23031     American Pale Ale (APA)
#  23531     American Pale Ale (APA)
#  24177     American Pale Ale (APA)
#  24190     American Pale Ale (APA)
#  24387     American Pale Ale (APA)
#  31924     American Pale Ale (APA)
#  33513            English Pale Ale
#  33686     American Pale Ale (APA)
#  39315     American Pale Ale (APA)
#  39474     American Pale Ale (APA)
#  43076     American Pale Ale (APA)
#  43355     American Pale Ale (APA)
#  43680     American Pale Ale (APA)
#  43976            English Pale Ale
#  44221         American Blonde Ale
#  46717     American Pale Ale (APA)
#  47422     American Pale Ale (APA)
#  47436            English Pale Ale
#  47690     American Pale Ale (APA)
#  52176            English Pale Ale
#  52184     American Pale Ale (APA)
#  55477     American Pale Ale (APA)
#  58105            English Pale Ale
#                     ...
#  99420            English Pale Ale
#  99673            Belgian Pale Ale
#  99694     American Pale Ale (APA)
#  101965    American Pale Ale (APA)
#  105236    American Pale Ale (APA)
#  105836    American Pale Ale (APA)
#  110466    American Pale Ale (APA)
#  111664           Belgian Pale Ale
#  111872    American Pale Ale (APA)
#  112520    American Pale Ale (APA)
#  120939    American Pale Ale (APA)
#  122171    American Pale Ale (APA)
#  123167    American Pale Ale (APA)
#  126547    American Pale Ale (APA)
#  128665    American Pale Ale (APA)
#  128953    American Pale Ale (APA)
#  136983    American Pale Ale (APA)
#  138074    American Pale Ale (APA)
#  138088    American Pale Ale (APA)
#  138130           English Pale Ale
#  138403    American Pale Ale (APA)
#  139834    American Pale Ale (APA)
#  142227    American Pale Ale (APA)
#  146476           English Pale Ale
#  146488    American Pale Ale (APA)
#  146511    American Pale Ale (APA)
#  148966    American Pale Ale (APA)
#  150655    American Pale Ale (APA)
#  151191    American Pale Ale (APA)
#  157978    American Pale Ale (APA)
#  Name: beer_style, Length: 75, dtype: object, "Samuel Smith's Oatmeal Stout", 51315    Oatmeal Stout
#  Name: beer_style, dtype: object, 'Orval Trappist Ale', 34190    Belgian Pale Ale
#  Name: beer_style, dtype: object, 'Dead Guy Ale', 46457    Maibock / Helles Bock
#  Name: beer_style, dtype: object, 'Ayinger Celebrator Doppelbock', 101044    Doppelbock
#  Name: beer_style, dtype: object, 'Weihenstephaner Hefeweissbier', 68531    Hefeweizen
#  Name: beer_style, dtype: object, 'Sierra Nevada Torpedo Extra IPA', 9106    American IPA
#  Name: beer_style, dtype: object, 'Prima Pils', 154331    German Pilsener
#  Name: beer_style, dtype: object, 'Racer 5 India Pale Ale', 15506    American IPA
#  Name: beer_style, dtype: object, 'Schneider Aventinus', 83646    Weizenbock
#  Name: beer_style, dtype: object, 'Founders KBS (Kentucky Breakfast Stout)', 3296    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Trois Pistoles', 36928    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Samuel Adams Octoberfest', 28741    Märzen / Oktoberfest
#  Name: beer_style, dtype: object, 'Hop Rod Rye', 15408    Rye Beer
#  Name: beer_style, dtype: object, 'Double Bastard Ale', 88377    American Strong Ale
#  Name: beer_style, dtype: object, 'Three Philosophers Belgian Style Blend (Quadrupel)', 76776    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'Samuel Adams Winter Lager', 31277    Bock
#  Name: beer_style, dtype: object, 'Tröegs Nugget Nectar', 40754    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Stone Smoked Porter', 88292    American Porter
#  Name: beer_style, dtype: object, 'Chimay Grande Réserve (Blue)', 24444    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Anchor Steam Beer', 131270    California Common / Steam Beer
#  Name: beer_style, dtype: object, 'Oatmeal Stout', 1395           Oatmeal Stout
#  4148           Oatmeal Stout
#  10944          Oatmeal Stout
#  11917          Oatmeal Stout
#  21017          Oatmeal Stout
#  21253          Oatmeal Stout
#  25613          Oatmeal Stout
#  32057          Oatmeal Stout
#  32600          Oatmeal Stout
#  33472          Oatmeal Stout
#  34192          Oatmeal Stout
#  40587          Oatmeal Stout
#  43075          Oatmeal Stout
#  43933          Oatmeal Stout
#  47275          Oatmeal Stout
#  50812          Oatmeal Stout
#  54101          Oatmeal Stout
#  59176          Oatmeal Stout
#  62152          Oatmeal Stout
#  62773          Oatmeal Stout
#  65679          Oatmeal Stout
#  67704          Oatmeal Stout
#  71780          Oatmeal Stout
#  72341          Oatmeal Stout
#  73858          Oatmeal Stout
#  78338          Oatmeal Stout
#  81350          Oatmeal Stout
#  83946          Oatmeal Stout
#  90820          Oatmeal Stout
#  90940          Oatmeal Stout
#  91534          Oatmeal Stout
#  95687          Oatmeal Stout
#  97490          Oatmeal Stout
#  99421     Milk / Sweet Stout
#  105131         Oatmeal Stout
#  106261         Oatmeal Stout
#  106586         Oatmeal Stout
#  107502         Oatmeal Stout
#  108127         Oatmeal Stout
#  118837         Oatmeal Stout
#  122198         Oatmeal Stout
#  123991         Oatmeal Stout
#  126572         Oatmeal Stout
#  128239         Oatmeal Stout
#  128264         Oatmeal Stout
#  128299         Oatmeal Stout
#  139916         Oatmeal Stout
#  141455         Oatmeal Stout
#  146780         Oatmeal Stout
#  147729         Oatmeal Stout
#  157315         Oatmeal Stout
#  Name: beer_style, dtype: object, "Samuel Smith's Imperial Stout", 51920    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Hoegaarden Original White Ale', 27259    Witbier
#  Name: beer_style, dtype: object, 'Oaked Arrogant Bastard Ale', 88567    American Strong Ale
#  Name: beer_style, dtype: object, 'Stone Sublimely Self-Righteous Ale', 85222    American Black Ale
#  Name: beer_style, dtype: object, 'Hop Wallop', 154662    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Alpha King Pale Ale', 132069    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Maudite', 34914    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Palo Santo Marron', 117712    American Brown Ale
#  Name: beer_style, dtype: object, 'Hennepin (Farmhouse Saison)', 75864    Saison / Farmhouse Ale
#  Name: beer_style, dtype: object, '120 Minute IPA', 118229    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'World Wide Stout', 117483    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Punkin Ale', 117467    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Porter', 176       American Porter
#  6551      American Porter
#  14859     American Porter
#  32027     American Porter
#  38519     American Porter
#  43029     American Porter
#  47433     American Porter
#  47468     American Porter
#  52530     American Porter
#  52738     American Porter
#  54587     American Porter
#  60028     American Porter
#  69808     American Porter
#  73687      English Porter
#  75149     American Porter
#  77648     American Porter
#  90571      English Porter
#  99704     American Porter
#  113430    American Porter
#  118753      Baltic Porter
#  120850    American Porter
#  120908    American Porter
#  121964      Baltic Porter
#  122562    American Porter
#  122807    American Porter
#  128172    American Porter
#  128433    American Porter
#  138448    American Porter
#  141524      Baltic Porter
#  141929    American Porter
#  142901    American Porter
#  146814      Baltic Porter
#  148560     English Porter
#  157144      Baltic Porter
#  157989    American Porter
#  Name: beer_style, dtype: object, "Bell's Expedition Stout", 93557    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Anchor Porter', 128027    American Porter
#  Name: beer_style, dtype: object, 'Newcastle Brown Ale', 155149    English Brown Ale
#  Name: beer_style, dtype: object, 'Trappistes Rochefort 8', 33625    Dubbel
#  Name: beer_style, dtype: object, 'Bourbon County Brand Stout', 58671    American Double / Imperial Stout
#  Name: beer_style, dtype: object, "Raison D'etre", 117087    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Fat Tire Amber Ale', 19902    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Chimay Tripel (White)', 24626    Tripel
#  Name: beer_style, dtype: object, 'Ten FIDY', 144918    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Golden Monkey', 152007    Tripel
#  Name: beer_style, dtype: object, 'Shakespeare Oatmeal Stout', 50135    Oatmeal Stout
#  Name: beer_style, dtype: object, 'Franziskaner Hefe-Weisse', 88471    Hefeweizen
#  Name: beer_style, dtype: object, 'Westmalle Trappist Tripel', 98132    Tripel
#  Name: beer_style, dtype: object, 'Great Lakes Edmund Fitzgerald Porter', 41984    American Porter
#  Name: beer_style, dtype: object, 'Samuel Adams Summer Ale', 27782    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Oktoberfest', 169       Märzen / Oktoberfest
#  11241     Märzen / Oktoberfest
#  12457     Märzen / Oktoberfest
#  14374     Märzen / Oktoberfest
#  18448     Märzen / Oktoberfest
#  21099     Märzen / Oktoberfest
#  33419     Märzen / Oktoberfest
#  35588     Märzen / Oktoberfest
#  35699     Märzen / Oktoberfest
#  43472     Märzen / Oktoberfest
#  43637     Märzen / Oktoberfest
#  47453     Märzen / Oktoberfest
#  52453     Märzen / Oktoberfest
#  52589             Vienna Lager
#  58042     Märzen / Oktoberfest
#  59552     Märzen / Oktoberfest
#  60255     Märzen / Oktoberfest
#  65701     Märzen / Oktoberfest
#  67856     Märzen / Oktoberfest
#  72684     Märzen / Oktoberfest
#  72966     Märzen / Oktoberfest
#  75783     Märzen / Oktoberfest
#  77665     Märzen / Oktoberfest
#  77734     Märzen / Oktoberfest
#  81395     Märzen / Oktoberfest
#  83463     Märzen / Oktoberfest
#  83974     Märzen / Oktoberfest
#  84388     Märzen / Oktoberfest
#  89507     Märzen / Oktoberfest
#  90426     Märzen / Oktoberfest
#                    ...
#  102210    Märzen / Oktoberfest
#  106263    Märzen / Oktoberfest
#  108614    Märzen / Oktoberfest
#  111860    Märzen / Oktoberfest
#  115039    Märzen / Oktoberfest
#  119936    Märzen / Oktoberfest
#  122035    Märzen / Oktoberfest
#  122338    Märzen / Oktoberfest
#  122412    Märzen / Oktoberfest
#  124582    Märzen / Oktoberfest
#  126704    Märzen / Oktoberfest
#  126873    Märzen / Oktoberfest
#  128237    Märzen / Oktoberfest
#  133298    Märzen / Oktoberfest
#  134497    Märzen / Oktoberfest
#  134641    Märzen / Oktoberfest
#  136742    Märzen / Oktoberfest
#  136828    Märzen / Oktoberfest
#  137637    Märzen / Oktoberfest
#  138067    Märzen / Oktoberfest
#  138390    Märzen / Oktoberfest
#  139749    Märzen / Oktoberfest
#  139835    Märzen / Oktoberfest
#  142205    Märzen / Oktoberfest
#  142899    Märzen / Oktoberfest
#  144321    Märzen / Oktoberfest
#  146179    Märzen / Oktoberfest
#  147831    Märzen / Oktoberfest
#  150645    Märzen / Oktoberfest
#  153228    Märzen / Oktoberfest
#  Name: beer_style, Length: 64, dtype: object, 'Blue Moon Belgian White', 35037    Witbier
#  Name: beer_style, dtype: object, 'Hop Stoopid', 135575    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Hercules Double IPA', 22509    American Double / Imperial IPA
#  Name: beer_style, dtype: object, "Bell's Oberon Ale", 93443    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Péché Mortel (Imperial Stout Au Cafe)', 25092    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'ApriHop', 117644    American IPA
#  Name: beer_style, dtype: object, 'Dreadnaught IPA', 132293    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Christmas Ale', 12703        Herbed / Spiced Beer
#  38638          English Barleywine
#  58894          American Brown Ale
#  72830               Winter Warmer
#  89505               Winter Warmer
#  102275              Winter Warmer
#  106335              Winter Warmer
#  107793     Scotch Ale / Wee Heavy
#  130606     Saison / Farmhouse Ale
#  149616    Belgian Strong Dark Ale
#  157986    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Sculpin India Pale Ale', 60814    American IPA
#  Name: beer_style, dtype: object, 'Indian Brown Ale', 116114    American Brown Ale
#  Name: beer_style, dtype: object, "Samuel Smith's Nut Brown Ale", 51159    English Brown Ale
#  Name: beer_style, dtype: object, 'Gonzo Imperial Porter', 26867    Baltic Porter
#  Name: beer_style, dtype: object, 'Smuttynose IPA "Finest Kind"', 110371    American IPA
#  Name: beer_style, dtype: object, 'Budweiser', 129980    American Adjunct Lager
#  Name: beer_style, dtype: object, 'Yuengling Traditional Lager', 147948    American Amber / Red Lager
#  Name: beer_style, dtype: object, 'Left Hand Milk Stout', 109636    Milk / Sweet Stout
#  Name: beer_style, dtype: object, "Founders Red's Rye PA", 2471    Rye Beer
#  Name: beer_style, dtype: object, 'Ommegang (Abbey Ale)', 73448    Dubbel
#  Name: beer_style, dtype: object, 'Samuel Adams Black Lager', 29752    Schwarzbier
#  Name: beer_style, dtype: object, 'IPA', 299                       American IPA
#  646                       American IPA
#  1422                      American IPA
#  1455                      American IPA
#  4255      English India Pale Ale (IPA)
#  6760                      American IPA
#  10757     English India Pale Ale (IPA)
#  17482     English India Pale Ale (IPA)
#  17677                     American IPA
#  21249                     American IPA
#  33398                     American IPA
#  36064     English India Pale Ale (IPA)
#  39308                     American IPA
#  39318                     American IPA
#  39449     English India Pale Ale (IPA)
#  42991                     American IPA
#  43195                     American IPA
#  43695                     American IPA
#  45512                     American IPA
#  45644                     American IPA
#  47402                     American IPA
#  52881                     American IPA
#  62768                     American IPA
#  67339                     American IPA
#  78664                     American IPA
#  89625                     American IPA
#  91266                     American IPA
#  97556                     American IPA
#  107937                    American IPA
#  112502    English India Pale Ale (IPA)
#  119732                    American IPA
#  121974                    American IPA
#  122023                    American IPA
#  122584    English India Pale Ale (IPA)
#  123170                    American IPA
#  128194                    American IPA
#  134348    English India Pale Ale (IPA)
#  138075                    American IPA
#  141948                    American IPA
#  146949                    American IPA
#  156730                    American IPA
#  Name: beer_style, dtype: object, 'Founders Centennial IPA', 2081    American IPA
#  Name: beer_style, dtype: object, 'Pabst Blue Ribbon (PBR)', 32119    American Adjunct Lager
#  Name: beer_style, dtype: object, 'Yeti Imperial Stout', 21929    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Burton Baton', 115881    American Double / Imperial IPA
#  Name: beer_style, dtype: object, "Bell's Special Double Cream Stout", 92287    American Stout
#  Name: beer_style, dtype: object, '#9', 145081    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Delirium Tremens', 137042    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Sierra Nevada Summerfest Lager', 7929    Czech Pilsener
#  Name: beer_style, dtype: object, 'Northern Hemisphere Harvest Wet Hop Ale', 8169    American IPA
#  Name: beer_style, dtype: object, 'Samuel Adams Noble Pils', 30480    Czech Pilsener
#  Name: beer_style, dtype: object, 'Heineken Lager Beer', 4220    Euro Pale Lager
#  Name: beer_style, dtype: object, 'Nut Brown Ale', 972        English Brown Ale
#  3948      American Brown Ale
#  4109       English Brown Ale
#  21019      English Brown Ale
#  21356     American Brown Ale
#  23533     American Brown Ale
#  24180      English Brown Ale
#  24227      English Brown Ale
#  24283      English Brown Ale
#  43691      English Brown Ale
#  45661     American Brown Ale
#  47472      English Brown Ale
#  48232      English Brown Ale
#  59335      English Brown Ale
#  63005      English Brown Ale
#  66648      English Brown Ale
#  67808      English Brown Ale
#  89624     American Brown Ale
#  90597      English Brown Ale
#  105848     English Brown Ale
#  130586    American Brown Ale
#  139898     English Brown Ale
#  147698     English Brown Ale
#  Name: beer_style, dtype: object, 'Maharaja', 63672    American Double / Imperial IPA
#  Name: beer_style, dtype: object, "Dale's Pale Ale", 144557    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Stella Artois', 141809    Euro Pale Lager
#  Name: beer_style, dtype: object, 'Paulaner Hefe-Weissbier Naturtrüb', 147133    Hefeweizen
#  Name: beer_style, dtype: object, 'Pumking', 14586    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Chimay Première (Red)', 24790    Dubbel
#  Name: beer_style, dtype: object, 'Duchesse De Bourgogne', 12317    Flanders Red Ale
#  Name: beer_style, dtype: object, 'The Abyss', 143156    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Green Flash West Coast I.P.A.', 18607    American IPA
#  Name: beer_style, dtype: object, 'Oak Aged Yeti Imperial Stout', 21818    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Chicory Stout', 113835    American Stout
#  Name: beer_style, dtype: object, 'Gumballhead', 132334    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Boddingtons Pub Ale', 8633    English Pale Ale
#  Name: beer_style, dtype: object, 'Blind Pig IPA', 112649    American IPA
#  Name: beer_style, dtype: object, 'Founders Dirty Bastard', 1852    Scotch Ale / Wee Heavy
#  Name: beer_style, dtype: object, 'Trappist Westvleteren 12', 148256    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'Titan IPA', 21594    American IPA
#  Name: beer_style, dtype: object, 'Bud Light', 129294    Light Lager
#  Name: beer_style, dtype: object, 'Double Simcoe IPA', 46316    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Mocha Porter', 48615     American Porter
#  137824    American Porter
#  Name: beer_style, dtype: object, 'Spaten Optimator', 90048    Doppelbock
#  Name: beer_style, dtype: object, 'Samuel Adams Old Fezziwig Ale', 29184    Winter Warmer
#  Name: beer_style, dtype: object, 'Pilsner Urquell', 4499    Czech Pilsener
#  Name: beer_style, dtype: object, 'Midas Touch Golden Elixir', 117421    Herbed / Spiced Beer
#  Name: beer_style, dtype: object, 'Sierra Nevada Southern Hemisphere Harvest Fresh Hop Ale', 7396    American IPA
#  Name: beer_style, dtype: object, 'Founders Imperial Stout', 1833    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Old Horizontal', 155050    American Barleywine
#  Name: beer_style, dtype: object, 'Creme Brulee (Imperial Milk Stout)', 15915    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Maximus', 107987           Belgian Strong Pale Ale
#  135049    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Anchor Liberty Ale', 129869    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Founders Double Trouble', 2880    American Double / Imperial IPA
#  Name: beer_style, dtype: object, '1554 Enlightened Black Ale', 20064    Belgian Dark Ale
#  Name: beer_style, dtype: object, 'Gulden Draak (Dark Triple)', 23844    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Samuel Adams White Ale', 27770    Witbier
#  Name: beer_style, dtype: object, 'Samuel Adams Cream Stout', 30855    Milk / Sweet Stout
#  Name: beer_style, dtype: object, 'Miller Lite', 112120    Light Lager
#  Name: beer_style, dtype: object, 'Heavy Seas - Loose Cannon (Hop3 Ale)', 119762    American IPA
#  Name: beer_style, dtype: object, 'Furious', 77369    American IPA
#  Name: beer_style, dtype: object, 'Salvator Doppel Bock', 146190    Doppelbock
#  Name: beer_style, dtype: object, 'Bass Pale Ale', 112152    English Pale Ale
#  Name: beer_style, dtype: object, 'Sierra Nevada Porter', 7706    American Porter
#  Name: beer_style, dtype: object, 'Samuel Adams Holiday Porter', 28553    American Porter
#  Name: beer_style, dtype: object, 'Guinness Extra Stout (Original)', 123664    Irish Dry Stout
#  Name: beer_style, dtype: object, 'Houblon Chouffe Dobbelen IPA Tripel', 149773    Belgian IPA
#  Name: beer_style, dtype: object, 'Sierra Nevada Stout', 3859    American Stout
#  Name: beer_style, dtype: object, "Fuller's London Porter", 113784    English Porter
#  Name: beer_style, dtype: object, 'Brooklyn Lager', 151406    American Amber / Red Lager
#  Name: beer_style, dtype: object, 'Lagunitas IPA', 135637    American IPA
#  Name: beer_style, dtype: object, "Samuel Smith's Winter Welcome Ale", 51047    Winter Warmer
#  Name: beer_style, dtype: object, 'Saison Dupont', 99923    Saison / Farmhouse Ale
#  Name: beer_style, dtype: object, 'Choklat', 15321    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Samuel Adams Chocolate Bock', 29559    Bock
#  Name: beer_style, dtype: object, 'Sierra Nevada Anniversary Ale (2007-2009)', 6978    American IPA
#  Name: beer_style, dtype: object, "Fuller's ESB", 112794    Extra Special / Strong Bitter (ESB)
#  Name: beer_style, dtype: object, 'Harvest Ale', 10916                    Märzen / Oktoberfest
#  12637                 American Pale Ale (APA)
#  14836     Extra Special / Strong Bitter (ESB)
#  38518                 American Pale Ale (APA)
#  45500                 American Pale Ale (APA)
#  45653     Extra Special / Strong Bitter (ESB)
#  46550                            American IPA
#  59294     Extra Special / Strong Bitter (ESB)
#  96718                        English Pale Ale
#  138952                           American IPA
#  148667                   Herbed / Spiced Beer
#  Name: beer_style, dtype: object, 'Old Stock Ale', 125948    Old Ale
#  Name: beer_style, dtype: object, 'Old Chub - Scottish Style Ale', 145091    Scotch Ale / Wee Heavy
#  Name: beer_style, dtype: object, 'Leffe Blonde', 96782    Belgian Pale Ale
#  Name: beer_style, dtype: object, 'Coors Light', 32973    Light Lager
#  Name: beer_style, dtype: object, 'Brutal Bitter Ale', 49390    American IPA
#  Name: beer_style, dtype: object, "G'Knight Imperial Red Ale", 144746    American Double / Imperial IPA
#  Name: beer_style, dtype: object, "Santa's Private Reserve Ale", 49037    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'St. Bernardus Prior 8', 149333    Dubbel
#  Name: beer_style, dtype: object, 'Samuel Adams Double Bock (Imperial Series)', 28214    Doppelbock
#  Name: beer_style, dtype: object, 'Westmalle Trappist Dubbel', 98457    Dubbel
#  Name: beer_style, dtype: object, 'Great Lakes Dortmunder Gold', 40069    Dortmunder / Export Lager
#  Name: beer_style, dtype: object, 'Samuel Adams Cherry Wheat', 30036    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Matilda', 58949    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, "Bell's Kalamazoo Stout", 93095    American Stout
#  Name: beer_style, dtype: object, 'Tröegs Hopback Amber Ale', 40405    American Amber / Red Ale
#  Name: beer_style, dtype: object, "Hop Ottin' IPA", 95090    American IPA
#  Name: beer_style, dtype: object, 'AleSmith IPA', 17884    American IPA
#  Name: beer_style, dtype: object, 'Unearthly (Imperial India Pale Ale)', 15077    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Damnation', 112455    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Anchor Old Foghorn', 130866    English Barleywine
#  Name: beer_style, dtype: object, 'Supplication', 113480    American Wild Ale
#  Name: beer_style, dtype: object, 'Harpoon IPA', 61653    American IPA
#  Name: beer_style, dtype: object, 'Spaten Oktoberfestbier Ur-Märzen', 89921    Märzen / Oktoberfest
#  Name: beer_style, dtype: object, 'Hobgoblin', 90727    English Brown Ale
#  Name: beer_style, dtype: object, "Bell's Java Stout", 91982    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Miller High Life', 109693    American Adjunct Lager
#  Name: beer_style, dtype: object, 'Pranqster', 125253    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Festina Pêche', 116035    Berliner Weissbier
#  Name: beer_style, dtype: object, 'Allagash White', 120583    Witbier
#  Name: beer_style, dtype: object, 'Great Lakes Burning River Pale Ale', 40309    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'India Pale Ale (IPA)', 33454    American IPA
#  63244    American IPA
#  Name: beer_style, dtype: object, 'Long Hammer IPA', 139390    American IPA
#  Name: beer_style, dtype: object, 'Weihenstephaner Korbinian', 68366    Doppelbock
#  Name: beer_style, dtype: object, 'Big Bear Black Stout', 16140    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Red Rocket Ale', 12674     American Pale Ale (APA)
#  15359    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Paulaner Oktoberfest-Märzen', 147306    Märzen / Oktoberfest
#  Name: beer_style, dtype: object, "Murphy's Irish Stout", 71385    Irish Dry Stout
#  Name: beer_style, dtype: object, 'Hazelnut Brown Nectar', 48917    American Brown Ale
#  Name: beer_style, dtype: object, 'Corona Extra', 90010    American Adjunct Lager
#  Name: beer_style, dtype: object, 'Tripel Karmeliet', 67419    Tripel
#  Name: beer_style, dtype: object, 'Don de Dieu', 36573    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'AleSmith Speedway Stout', 17833    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Snake Dog IPA', 26687    American IPA
#  Name: beer_style, dtype: object, 'St. Bernardus Tripel', 149664    Tripel
#  Name: beer_style, dtype: object, 'Tröegs Mad Elf', 40066    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, "Samuel Smith's, The Famous Taddy Porter", 51701    English Porter
#  Name: beer_style, dtype: object, 'Samuel Adams Irish Red', 28290    Irish Red Ale
#  Name: beer_style, dtype: object, 'Samichlaus Bier', 18689    Doppelbock
#  92740    Doppelbock
#  Name: beer_style, dtype: object, 'Immort Ale', 117333    American Strong Ale
#  Name: beer_style, dtype: object, 'Negra Modelo', 90134    Munich Dunkel Lager
#  Name: beer_style, dtype: object, 'Raging Bitch Belgian-Style IPA', 26175    Belgian IPA
#  Name: beer_style, dtype: object, "Brown Shugga'", 134716    American Strong Ale
#  Name: beer_style, dtype: object, 'Great Lakes Blackout Stout', 41632    Russian Imperial Stout
#  Name: beer_style, dtype: object, "Monk's Café Flemish Sour Ale", 23588    Flanders Oud Bruin
#  Name: beer_style, dtype: object, 'Cappuccino Stout', 136003    American Double / Imperial Stout
#  Name: beer_style, dtype: object, "Leinenkugel's Sunset Wheat", 101477    Witbier
#  Name: beer_style, dtype: object, 'Hibernation Ale', 21599    Old Ale
#  Name: beer_style, dtype: object, 'Vanilla Porter', 6763      American Porter
#  52150     American Porter
#  68757     American Porter
#  106443    American Porter
#  123987    American Porter
#  147521    American Porter
#  Name: beer_style, dtype: object, "Fuller's London Pride", 113340    English Pale Ale
#  Name: beer_style, dtype: object, 'Double Jack', 55269     American Double / Imperial IPA
#  108308    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Sierra Nevada Kellerweis Hefeweizen', 6821    Hefeweizen
#  Name: beer_style, dtype: object, 'Hazed & Infused', 68151    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Stone Levitation Ale', 84972    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Terrapin Coffee Oatmeal Imperial Stout', 53388    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Stone Pale Ale', 88379    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Adam', 103424    Old Ale
#  Name: beer_style, dtype: object, 'Piraat Ale', 22751    Belgian IPA
#  Name: beer_style, dtype: object, 'Old Ruffian Barley Wine', 21859    American Barleywine
#  Name: beer_style, dtype: object, 'Black Butte Porter', 143292    American Porter
#  Name: beer_style, dtype: object, 'IPA (India Pale Ale)', 15644    American IPA
#  Name: beer_style, dtype: object, 'Green Flash Imperial India Pale Ale', 19122    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Blanche De Chambly', 36750    Witbier
#  Name: beer_style, dtype: object, 'Doggie Style Classic Pale Ale', 24964    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Rare Vos (Amber Ale)', 74100    Belgian Pale Ale
#  Name: beer_style, dtype: object, 'Great Lakes Eliot Ness', 41428    Vienna Lager
#  Name: beer_style, dtype: object, 'Lindemans Framboise', 78901    Lambic - Fruit
#  Name: beer_style, dtype: object, 'Redhook ESB', 139235    Extra Special / Strong Bitter (ESB)
#  Name: beer_style, dtype: object, 'Saison Du BUFF', 87534     Saison / Farmhouse Ale
#  115419    Saison / Farmhouse Ale
#  153239    Saison / Farmhouse Ale
#  Name: beer_style, dtype: object, 'La Terrible', 36338    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'YuleSmith (Summer)', 17948    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Founders Devil Dancer', 1704    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Founders Porter', 3395    American Porter
#  Name: beer_style, dtype: object, 'Salvation', 64528     Belgian Strong Pale Ale
#  113729    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, "Bell's Porter", 92428    American Porter
#  Name: beer_style, dtype: object, 'Smuttynose Old Brown Dog Ale', 110486    American Brown Ale
#  Name: beer_style, dtype: object, 'Samuel Adams Cranberry Lambic', 31347    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Olde School Barleywine', 118007    American Barleywine
#  Name: beer_style, dtype: object, 'Brooklyn East India Pale Ale', 151748    English India Pale Ale (IPA)
#  Name: beer_style, dtype: object, 'Sierra Nevada Tumbler Autumn Brown Ale', 7616    American Brown Ale
#  Name: beer_style, dtype: object, 'Rodenbach Grand Cru', 106118    Flanders Red Ale
#  Name: beer_style, dtype: object, 'Éphémère (Apple)', 36482    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Brooklyn Monster Ale', 152171    English Barleywine
#  Name: beer_style, dtype: object, "New Holland Dragon's Milk Oak Barrel Ale", 127783    American Stout
#  Name: beer_style, dtype: object, 'Moose Drool Brown Ale', 97693    American Brown Ale
#  Name: beer_style, dtype: object, 'Dark Lord Imperial Stout', 132976    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Samuel Adams Boston Ale (Stock Ale)', 30954    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Hog Heaven Barley Wine', 62991    American Barleywine
#  Name: beer_style, dtype: object, 'Turbodog', 38881    English Brown Ale
#  Name: beer_style, dtype: object, 'Great Lakes Nosferatu', 41061    American Strong Ale
#  Name: beer_style, dtype: object, "Ruedrich's Red Seal Ale", 124509    American Amber / Red Ale
#  Name: beer_style, dtype: object, "Stoudt's Fat Dog (Imperial Oatmeal Stout)", 5036    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Widmer Hefeweizen', 74283    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Old Speckled Hen', 124016    English Pale Ale
#  Name: beer_style, dtype: object, "A Little Sumpin' Sumpin' Ale", 135063    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Aecht Schlenkerla Rauchbier Märzen', 4318    Rauchbier
#  Name: beer_style, dtype: object, "Honker's Ale", 58539    English Bitter
#  Name: beer_style, dtype: object, 'Old Scratch Amber Lager', 24710    California Common / Steam Beer
#  Name: beer_style, dtype: object, 'Beer Geek Breakfast', 85141    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Troegenator Double Bock', 39970    Doppelbock
#  Name: beer_style, dtype: object, 'La Chouffe', 149812    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Smuttynose Big A IPA (Big Beer Series)', 110878    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Red Stripe Jamaican Lager', 16034    American Adjunct Lager
#  Name: beer_style, dtype: object, 'Trappistes Rochefort 6', 34092    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Imperial IPA', 24260     American Double / Imperial IPA
#  43401     American Double / Imperial IPA
#  58324     American Double / Imperial IPA
#  68056     American Double / Imperial IPA
#  94980     American Double / Imperial IPA
#  105063    American Double / Imperial IPA
#  119774    American Double / Imperial IPA
#  122033    American Double / Imperial IPA
#  124027    American Double / Imperial IPA
#  138442    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Hopsickle Imperial India Pale Ale', 37896    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Obsidian Stout', 142947    American Stout
#  Name: beer_style, dtype: object, 'Brooklyn Brown Ale', 151520    American Brown Ale
#  Name: beer_style, dtype: object, 'Consecration', 112745    American Wild Ale
#  Name: beer_style, dtype: object, 'Blithering Idiot', 46907    English Barleywine
#  Name: beer_style, dtype: object, "Bell's Cherry Stout", 91959    American Stout
#  Name: beer_style, dtype: object, 'Pumpkinhead Ale', 70794     Pumpkin Ale
#  140363    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Samuel Adams Imperial Stout', 28704    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Double Dog Double Pale Ale', 26103    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Stone Cali-Belgique', 85510    Belgian IPA
#  Name: beer_style, dtype: object, 'Weihenstephaner Hefeweissbier Dunkel', 68283    Dunkelweizen
#  Name: beer_style, dtype: object, 'Smuttynose Robust Porter', 110644    American Porter
#  Name: beer_style, dtype: object, 'Wisconsin Belgian Red', 44851    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Flower Power India Pale Ale', 66299    American IPA
#  Name: beer_style, dtype: object, 'Ranger', 20716    American IPA
#  Name: beer_style, dtype: object, 'Alaskan Smoked Porter', 157550    American Porter
#  Name: beer_style, dtype: object, 'Third Coast Old Ale', 92995    American Barleywine
#  Name: beer_style, dtype: object, 'Bitburger Premium Pils', 148569    German Pilsener
#  Name: beer_style, dtype: object, 'Temptation', 113592         American Wild Ale
#  122794    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Delirium Noël', 137140    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Fraoch Heather Ale', 97934    Scottish Gruit / Ancient Herbed Ale
#  Name: beer_style, dtype: object, 'Schneider Aventinus Weizen-Eisbock', 83842    Eisbock
#  Name: beer_style, dtype: object, "Bell's Best Brown", 92836    English Brown Ale
#  Name: beer_style, dtype: object, 'Censored', 133223    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Dark Horse Crooked Tree IPA', 69513    American IPA
#  Name: beer_style, dtype: object, 'Union Jack India Pale Ale', 57067    American IPA
#  Name: beer_style, dtype: object, 'Samuel Adams Latitude 48 IPA', 31190    American IPA
#  Name: beer_style, dtype: object, 'Squall IPA', 116005    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Robert The Bruce Scottish Ale', 132214    Scottish Ale
#  Name: beer_style, dtype: object, 'Warsteiner Premium Verum', 57854    German Pilsener
#  Name: beer_style, dtype: object, 'Allagash Curieux (Bourbon Barrel-Aged Tripel)', 121341    Tripel
#  Name: beer_style, dtype: object, "Killian's Irish Red", 34868    American Amber / Red Lager
#  Name: beer_style, dtype: object, 'Allagash Dubbel Ale', 120967    Dubbel
#  Name: beer_style, dtype: object, 'Great Lakes Commodore Perry IPA', 41707    English India Pale Ale (IPA)
#  Name: beer_style, dtype: object, 'Post Road Pumpkin Ale', 152200    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Smuttynose Pumpkin Ale', 111370    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Delirium Nocturnum', 137049    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Brother Thelonious', 125433    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'SkullSplitter', 147789    Scotch Ale / Wee Heavy
#  Name: beer_style, dtype: object, 'Road Dog Porter', 26280    American Porter
#  Name: beer_style, dtype: object, "He'Brew Bittersweet Lenny's R.I.P.A.", 62224    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Smuttynose Imperial Stout (Big Beer Series)', 110730    Russian Imperial Stout
#  Name: beer_style, dtype: object, "Fuller's 1845", 113791    English Strong Ale
#  Name: beer_style, dtype: object, 'XS Imperial India Pale Ale', 49335    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Hefeweizen', 130                    Hefeweizen
#  239                    Hefeweizen
#  1502                   Hefeweizen
#  10934                  Hefeweizen
#  15913                  Hefeweizen
#  17417                  Hefeweizen
#  18708                  Hefeweizen
#  21362                  Hefeweizen
#  25390                  Hefeweizen
#  38639                  Hefeweizen
#  43672                  Hefeweizen
#  52568                  Hefeweizen
#  62155                  Hefeweizen
#  71205                  Hefeweizen
#  78718     American Pale Wheat Ale
#  81518                  Hefeweizen
#  83426                  Hefeweizen
#  83972                  Hefeweizen
#  89607                  Hefeweizen
#  90332     American Pale Wheat Ale
#  90811                  Hefeweizen
#  91438                  Hefeweizen
#  95719                  Hefeweizen
#  95788                  Hefeweizen
#  100227                 Hefeweizen
#  100247    American Pale Wheat Ale
#  100285                 Hefeweizen
#  111873                 Hefeweizen
#  122566                 Hefeweizen
#  122808                 Hefeweizen
#  126705                 Hefeweizen
#  133270                 Hefeweizen
#  133310                 Hefeweizen
#  135586                 Hefeweizen
#  137605                 Hefeweizen
#  138432                 Hefeweizen
#  142214                 Hefeweizen
#  Name: beer_style, dtype: object, 'Köstritzer Schwarzbier', 114828    Schwarzbier
#  Name: beer_style, dtype: object, 'Hacker-Pschorr Hefe Weisse Natürtrub', 11297    Hefeweizen
#  Name: beer_style, dtype: object, 'Old Viscosity', 13393    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Chipotle Ale', 48798    Chile Beer
#  Name: beer_style, dtype: object, 'Guinness Foreign Extra Stout', 123787    Foreign / Export Stout
#  Name: beer_style, dtype: object, 'Moonglow Weizenbock', 153881    Weizenbock
#  Name: beer_style, dtype: object, 'Cuvée Van De Keizer Blauw (Blue)', 152674    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Old Jubilation', 63104    Old Ale
#  Name: beer_style, dtype: object, 'Hairy Eyeball Ale', 133346    American Strong Ale
#  Name: beer_style, dtype: object, '2XIPA', 14318    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Founders Curmudgeon (Old Ale)', 3225    Old Ale
#  Name: beer_style, dtype: object, 'White Rascal', 63383    Witbier
#  Name: beer_style, dtype: object, 'The Czar', 63803    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Sam Adams Light', 30765    Light Lager
#  Name: beer_style, dtype: object, 'B.O.R.I.S. The Crusher Oatmeal-Imperial Stout', 529    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Ayinger Bräu Weisse', 102715    Hefeweizen
#  Name: beer_style, dtype: object, 'Shiner Bock', 100484    Bock
#  Name: beer_style, dtype: object, 'Budweiser American Ale', 129543    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Imperial Pumpkin Ale', 46227    Pumpkin Ale
#  90664    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Sierra Nevada Glissade Golden Bock', 8608    Maibock / Helles Bock
#  Name: beer_style, dtype: object, 'Lindemans Gueuze Cuvée René', 78763    Gueuze
#  Name: beer_style, dtype: object, 'Founders Backwoods Bastard', 1770    Scotch Ale / Wee Heavy
#  Name: beer_style, dtype: object, 'Barney Flats Oatmeal Stout', 95264    Oatmeal Stout
#  Name: beer_style, dtype: object, 'Heavy Seas - Peg Leg (Imperial Stout)', 120452    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Ommegang Witte', 76088    Witbier
#  Name: beer_style, dtype: object, 'Dundee Original Honey Brown Lager', 11811    American Amber / Red Lager
#  Name: beer_style, dtype: object, 'Raspberry Tart', 44488    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Lagunitas Lucky 13 Mondo Large Red Ale', 135961    American Amber / Red Ale
#  Name: beer_style, dtype: object, "Monty Python's Holy Grail Ale", 3862    English Pale Ale
#  Name: beer_style, dtype: object, 'Pere Jacques', 58197    Dubbel
#  Name: beer_style, dtype: object, 'Tire Bite Golden Ale', 26296    Kölsch
#  Name: beer_style, dtype: object, "Smithwick's", 122147    Irish Red Ale
#  Name: beer_style, dtype: object, 'Beamish Irish Stout', 137426    Irish Dry Stout
#  Name: beer_style, dtype: object, 'Lion Stout', 39376    Foreign / Export Stout
#  Name: beer_style, dtype: object, "Miles Davis' Bitches Brew", 115738    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Espresso Oak Aged Yeti Imperial Stout', 21902    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'XS Old Crustacean', 49529    American Barleywine
#  Name: beer_style, dtype: object, 'La Folie', 20269    Flanders Red Ale
#  Name: beer_style, dtype: object, "Merry Monks' Ale", 46298    Tripel
#  Name: beer_style, dtype: object, 'CoCoNut Porter', 64598    American Porter
#  74843    American Porter
#  Name: beer_style, dtype: object, 'Schneider Weisse Original', 81838    Hefeweizen
#  Name: beer_style, dtype: object, 'Sapporo Premium Beer', 98200    Japanese Rice Lager
#  Name: beer_style, dtype: object, 'Circus Boy', 145344    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Founders CBS Imperial Stout', 1626    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Olde GnarlyWine', 135622    American Barleywine
#  Name: beer_style, dtype: object, "Buffalo Bill's Pumpkin Ale", 155204    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Terrapin Rye Pale Ale', 53566    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Coffee Bender', 77345    American Brown Ale
#  Name: beer_style, dtype: object, 'Franziskaner Hefe-Weisse Dunkel', 89779    Dunkelweizen
#  Name: beer_style, dtype: object, 'Hops Infusion', 46765    American IPA
#  Name: beer_style, dtype: object, 'Fred', 101572    American Strong Ale
#  Name: beer_style, dtype: object, "Bell's Pale Ale", 94218    American Pale Ale (APA)
#  Name: beer_style, dtype: object, "A Little Sumpin' Wild", 136222    Belgian IPA
#  Name: beer_style, dtype: object, 'Weihenstephaner Kristallweissbier', 67915    Kristalweizen
#  Name: beer_style, dtype: object, 'Insanity', 46104    English Barleywine
#  Name: beer_style, dtype: object, "Samuel Smith's India Ale", 51594    English India Pale Ale (IPA)
#  Name: beer_style, dtype: object, 'Harp Lager', 119606    Euro Pale Lager
#  Name: beer_style, dtype: object, 'Trappist Westvleteren 8', 148386    Dubbel
#  Name: beer_style, dtype: object, 'Horn Dog Barley Wine Style Ale', 26936    English Barleywine
#  Name: beer_style, dtype: object, 'Ayinger Oktober Fest-Märzen', 102647    Märzen / Oktoberfest
#  Name: beer_style, dtype: object, 'Sweetwater IPA', 12008    American IPA
#  Name: beer_style, dtype: object, 'The Reverend', 63563    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'Brooklyn Local 1', 151260    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Harpoon Winter Warmer', 61219    Winter Warmer
#  Name: beer_style, dtype: object, 'Mirror Pond Pale Ale', 143699    American Pale Ale (APA)
#  Name: beer_style, dtype: object, "30th Anniversary - Fritz And Ken's Ale", 8067    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Pliny The Younger', 112953    American Double / Imperial IPA
#  Name: beer_style, dtype: object, '312 Urban Wheat', 58093    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Stone 15th Anniversary Escondidian Imperial Black IPA', 88185    American Black Ale
#  Name: beer_style, dtype: object, 'Old Heathen Imperial Stout', 46033    Russian Imperial Stout
#  Name: beer_style, dtype: object, "Bell's Amber Ale", 89299    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Rolling Rock Extra Pale', 60045    American Adjunct Lager
#  Name: beer_style, dtype: object, 'American Amber Ale', 49881    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Mojo IPA', 67490    American IPA
#  Name: beer_style, dtype: object, 'Budweiser Budvar', 85723    Czech Pilsener
#  Name: beer_style, dtype: object, "Samuel Smith's Old Brewery Pale Ale", 50677    English Pale Ale
#  Name: beer_style, dtype: object, 'Big Eye IPA', 60600    American IPA
#  Name: beer_style, dtype: object, 'Allagash Tripel Ale', 121603    Tripel
#  Name: beer_style, dtype: object, 'Samuel Adams Imperial White', 28611    Witbier
#  Name: beer_style, dtype: object, "Raison D'extra", 115808    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'New Holland Mad Hatter India Pale Ale', 127368    American IPA
#  Name: beer_style, dtype: object, 'Samuel Adams Blackberry Witbier', 30616    Witbier
#  Name: beer_style, dtype: object, "Stoudt's Double IPA (India Pale Ale)", 4982    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Full Sail IPA', 83028    American IPA
#  Name: beer_style, dtype: object, 'Grolsch Premium Lager', 126763    Euro Pale Lager
#  Name: beer_style, dtype: object, 'Great Lakes Christmas Ale', 41521    Winter Warmer
#  Name: beer_style, dtype: object, 'Hop 15', 13137    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Bender', 77081    American Brown Ale
#  Name: beer_style, dtype: object, 'Sawtooth Ale', 47470                     American Blonde Ale
#  109352    Extra Special / Strong Bitter (ESB)
#  Name: beer_style, dtype: object, '21st Amendment IPA', 150912    American IPA
#  Name: beer_style, dtype: object, 'Samuel Adams Scotch Ale', 28432    Scotch Ale / Wee Heavy
#  Name: beer_style, dtype: object, 'Warsteiner Premium Dunkel', 57865    Munich Dunkel Lager
#  Name: beer_style, dtype: object, 'Gemini (Imperial Blended Ale)', 15812    American Strong Ale
#  Name: beer_style, dtype: object, 'Siberian Night Imperial Stout', 45714    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Jubelale', 143549    Winter Warmer
#  Name: beer_style, dtype: object, 'Fresh Hop Pale Ale', 22842    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Life & Limb', 9397    American Strong Ale
#  Name: beer_style, dtype: object, 'Sierra Nevada ESB (Early Spring Beer)', 6927    Extra Special / Strong Bitter (ESB)
#  Name: beer_style, dtype: object, 'Dos Equis Amber Lager', 61841    Vienna Lager
#  Name: beer_style, dtype: object, 'Wipeout I.P.A.', 13444    American IPA
#  Name: beer_style, dtype: object, 'J.W. Lees Vintage Harvest Ale', 100845    English Barleywine
#  Name: beer_style, dtype: object, 'Founders Pale Ale', 2063    American Pale Ale (APA)
#  Name: beer_style, dtype: object, 'Juniper Pale Ale', 50578    Herbed / Spiced Beer
#  Name: beer_style, dtype: object, 'New Holland The Poet', 126306    Oatmeal Stout
#  Name: beer_style, dtype: object, 'DreamWeaver Wheat', 40646    Hefeweizen
#  Name: beer_style, dtype: object, 'Double Stout', 17551                       English Stout
#  19000    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Hacker-Pschorr Oktoberfest-Märzen', 11389    Märzen / Oktoberfest
#  Name: beer_style, dtype: object, 'Harpoon Leviathan - Imperial IPA', 61211    American Double / Imperial IPA
#  Name: beer_style, dtype: object, 'Purple Haze', 39012     Fruit / Vegetable Beer
#  147551    Fruit / Vegetable Beer
#  Name: beer_style, dtype: object, 'Trippel Belgian Style Ale', 20495    Tripel
#  Name: beer_style, dtype: object, 'Cantillon Kriek 100% Lambic', 48079    Lambic - Fruit
#  Name: beer_style, dtype: object, 'Bam Bière', 56740    Saison / Farmhouse Ale
#  Name: beer_style, dtype: object, 'La Trappe Quadrupel (Koningshoeven / Dominus)', 37119    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'Fantôme Saison', 141099    Saison / Farmhouse Ale
#  Name: beer_style, dtype: object, 'Chocolate Indulgence Stout', 76785    Belgian Dark Ale
#  Name: beer_style, dtype: object, "Thomas Hardy's Ale (2003-2008)", 146879    Old Ale
#  Name: beer_style, dtype: object, 'Oro De Calabaza', 56478    Bière de Garde
#  Name: beer_style, dtype: object, 'Belhaven Scottish Ale', 73544    Scottish Ale
#  Name: beer_style, dtype: object, 'Green Flash Hop Head Red Ale', 18738    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Heresy', 47089    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Yuengling Black & Tan', 147832    Black & Tan
#  Name: beer_style, dtype: object, 'Founders Harvest Ale', 2045    American IPA
#  Name: beer_style, dtype: object, 'Dark Horse Double Crooked Tree IPA', 70478    American Double / Imperial IPA
#  Name: beer_style, dtype: object, '471 IPA', 106585    American Double / Imperial IPA
#  Name: beer_style, dtype: object, "Mephistopheles' Stout", 61628    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Pangaea', 117682    Belgian Strong Pale Ale
#  Name: beer_style, dtype: object, 'Brooklyn Oktoberfest Beer', 152413    Märzen / Oktoberfest
#  Name: beer_style, dtype: object, 'Stone 12th Anniversary Bitter Chocolate Oatmeal Stout', 88915    American Double / Imperial Stout
#  Name: beer_style, dtype: object, "St. Peter's Cream Stout", 144040    Milk / Sweet Stout
#  Name: beer_style, dtype: object, 'Cadillac Mountain Stout', 121863    American Stout
#  Name: beer_style, dtype: object, 'Maredsous 10 - Triple', 96159    Tripel
#  Name: beer_style, dtype: object, 'Duck-Rabbit Milk Stout', 84985    Milk / Sweet Stout
#  Name: beer_style, dtype: object, 'Hi.P.A.', 145827    American IPA
#  Name: beer_style, dtype: object, 'Brooklyn Black OPS', 151410    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Samuel Adams Hallertau Imperial Pilsner', 30904    American Double / Imperial Pilsner
#  Name: beer_style, dtype: object, 'Alpha Klaus Christmas (Xmas) Porter', 132339    American Porter
#  Name: beer_style, dtype: object, 'Weihenstephaner Vitus', 68469    Weizenbock
#  Name: beer_style, dtype: object, 'Samuel Adams Hefeweizen', 28149    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Hell Hath No Fury Ale', 94156    Belgian Strong Dark Ale
#  Name: beer_style, dtype: object, 'Blue Moon Harvest Moon Pumpkin Ale', 35210    Pumpkin Ale
#  Name: beer_style, dtype: object, 'Jai Alai IPA', 14023    American IPA
#  Name: beer_style, dtype: object, 'Terrapin Big Hoppy Monster', 53912    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Schneider-Brooklyner Hopfen-Weisse', 83476    Weizenbock
#  Name: beer_style, dtype: object, 'Theobroma', 116194    Chile Beer
#  Name: beer_style, dtype: object, 'Parabola', 54733    Russian Imperial Stout
#  Name: beer_style, dtype: object, 'Yakima Glory', 154865    American Black Ale
#  Name: beer_style, dtype: object, 'Stone 13th Anniversary Ale', 87353    American Strong Ale
#  Name: beer_style, dtype: object, 'Maredsous 8 - Dubbel', 96516    Dubbel
#  Name: beer_style, dtype: object, 'Erdinger Weissbier', 81637    Hefeweizen
#  Name: beer_style, dtype: object, "Brooklyn Ale / Pennant Ale '55", 151155    English Pale Ale
#  Name: beer_style, dtype: object, 'Blue Moon Winter Abbey Ale', 34650    Dubbel
#  Name: beer_style, dtype: object, 'Jahva (Imperial Coffee Stout)', 15464    American Double / Imperial Stout
#  Name: beer_style, dtype: object, "McEwan's Scotch Ale", 156307    Scotch Ale / Wee Heavy
#  Name: beer_style, dtype: object, 'Samuel Adams Triple Bock', 28262    American Strong Ale
#  Name: beer_style, dtype: object, 'Labatt Blue', 120267    American Adjunct Lager
#  Name: beer_style, dtype: object, 'La Roja', 56671    American Wild Ale
#  Name: beer_style, dtype: object, 'Old Engine Oil', 148430    English Porter
#  Name: beer_style, dtype: object, 'Pannepot', 34484    Quadrupel (Quad)
#  98926    Quadrupel (Quad)
#  Name: beer_style, dtype: object, 'Terrapin Hopsecutioner', 53324    American IPA
#  Name: beer_style, dtype: object, 'Night Stalker', 59663    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'UFO Hefeweizen', 61289    American Pale Wheat Ale
#  Name: beer_style, dtype: object, 'Samuel Adams Honey Porter', 28858    English Porter
#  Name: beer_style, dtype: object, 'Cantillon Rosé De Gambrinus', 47792    Lambic - Fruit
#  Name: beer_style, dtype: object, 'Tröegs Sunshine Pils', 40251    German Pilsener
#  Name: beer_style, dtype: object, 'Double Barrel Ale', 57328    English Pale Ale
#  Name: beer_style, dtype: object, 'Whirlwind Witbier', 153779    Witbier
#  Name: beer_style, dtype: object, 'Abbey Belgian Style Ale', 19505    Dubbel
#  Name: beer_style, dtype: object, "Mama's Little Yella Pils", 144832    Czech Pilsener
#  Name: beer_style, dtype: object, 'Shock Top Belgian White', 130326    Witbier
#  Name: beer_style, dtype: object, "Foster's Lager", 135667    American Adjunct Lager
#  Name: beer_style, dtype: object, 'Pumpkin Ale', 3640                 Pumpkin Ale
#  18447                Pumpkin Ale
#  21077                Pumpkin Ale
#  24230     Fruit / Vegetable Beer
#  25459                Pumpkin Ale
#  31972                Pumpkin Ale
#  33307                Pumpkin Ale
#  35402                Pumpkin Ale
#  54651         English Strong Ale
#  59794                Pumpkin Ale
#  62166                Pumpkin Ale
#  73357                Pumpkin Ale
#  77693                Pumpkin Ale
#  78039                Pumpkin Ale
#  83435                Pumpkin Ale
#  90806                Pumpkin Ale
#  108080               Pumpkin Ale
#  111665               Pumpkin Ale
#  112568               Pumpkin Ale
#  119781               Pumpkin Ale
#  128217               Pumpkin Ale
#  134076               Pumpkin Ale
#  136736               Pumpkin Ale
#  139914               Pumpkin Ale
#  142199               Pumpkin Ale
#  146414               Pumpkin Ale
#  148514               Pumpkin Ale
#  Name: beer_style, dtype: object, 'Double Bag', 16254    Altbier
#  Name: beer_style, dtype: object, 'Mothership Wit (Organic Wheat Beer)', 20583    Witbier
#  Name: beer_style, dtype: object, 'Amber Ale', 3626      American Amber / Red Ale
#  3950      American Amber / Red Ale
#  39371     American Amber / Red Ale
#  43159     American Amber / Red Ale
#  45670     American Amber / Red Ale
#  53278     American Amber / Red Ale
#  55246     American Amber / Red Ale
#  66872     American Amber / Red Ale
#  67897     American Amber / Red Ale
#  69393     American Amber / Red Ale
#  72620     American Amber / Red Ale
#  73832     American Amber / Red Ale
#  78373     American Amber / Red Ale
#  81788     American Amber / Red Ale
#  82137     American Amber / Red Ale
#  91428     American Amber / Red Ale
#  94568     American Amber / Red Ale
#  97342     American Amber / Red Ale
#  105240    American Amber / Red Ale
#  107822    American Amber / Red Ale
#  110436    American Amber / Red Ale
#  120664    American Amber / Red Ale
#  120852    American Amber / Red Ale
#  120940    American Amber / Red Ale
#  122187    American Amber / Red Ale
#  123163    American Amber / Red Ale
#  130562    American Amber / Red Ale
#  130587    American Amber / Red Ale
#  134643    American Amber / Red Ale
#  136659    American Amber / Red Ale
#  138251    American Amber / Red Ale
#  146489    American Amber / Red Ale
#  150648    American Amber / Red Ale
#  Name: beer_style, dtype: object, 'Oat (Imperial Oatmeal Stout)', 15634    American Double / Imperial Stout
#  Name: beer_style, dtype: object, 'Weihenstephaner Original', 66242    Munich Helles Lager
#  Name: beer_style, dtype: object, ...]

# %%
beer_and_style[
# Out:
# 125480    Russian Imperial Stout
# Name: beer_style, dtype: object

# %%
top_beers[idxs]
beers_lookup = review_df[['beer_name', 'beer_beerid', 'beer_style', 'brewery_name']].drop_duplicates()
beers_lookup[beers_lookup['beer_name'].isin(top_beers[idxs])]
# review_df[review_df['beer_name'].isin(top_beers[idxs])]
# Out:
#                                          beer_name  beer_beerid  \
# 657                                       Pale Ale        13009
# 975                       Founders Breakfast Stout        11757
# 1228                                      Pale Ale        25656
# 1395                                 Oatmeal Stout        73769
# 3296       Founders KBS (Kentucky Breakfast Stout)        19960
# 4106                                      Pale Ale        28951
# 4148                                 Oatmeal Stout         6033
# 6745                                India Pale Ale        36312
# 6767                                      Pale Ale        24997
# 7522                 Sierra Nevada Celebration Ale         1904
# 7552    Sierra Nevada Bigfoot Barleywine Style Ale         2671
# 7845                        Sierra Nevada Pale Ale          276
# 9106               Sierra Nevada Torpedo Extra IPA        30420
# 10175                               India Pale Ale        47297
# 10944                                Oatmeal Stout        10705
# 11917                                Oatmeal Stout        29707
# 11924                                     Pale Ale        43116
# 12629                                     Pale Ale         5939
# 15408                                  Hop Rod Rye         3158
# 15506                       Racer 5 India Pale Ale         2751
# 17408                                     Pale Ale        55960
# 20903                               India Pale Ale        25562
# 21017                                Oatmeal Stout        20796
# 21020                               India Pale Ale         7739
# 21072                               India Pale Ale        24222
# 21118                               India Pale Ale         5626
# 21119                               Imperial Stout        10368
# 21253                                Oatmeal Stout         6233
# 23031                                     Pale Ale        69647
# 23531                                     Pale Ale        37938
# ...                                            ...          ...
# 142226                              India Pale Ale        28729
# 142227                                    Pale Ale         8652
# 142664                              India Pale Ale        60312
# 142892                              India Pale Ale         4357
# 146458                              Imperial Stout        16202
# 146476                                    Pale Ale        22853
# 146477                              India Pale Ale        19780
# 146488                                    Pale Ale        44190
# 146511                                    Pale Ale        30681
# 146780                               Oatmeal Stout        13065
# 146782                              India Pale Ale        14502
# 146801                              India Pale Ale         3175
# 147631                              Imperial Stout        71716
# 147729                               Oatmeal Stout         7076
# 148873                              Imperial Stout         7317
# 148966                                    Pale Ale         1238
# 149081                        St. Bernardus Abt 12         1708
# 150650                              India Pale Ale        71545
# 150655                                    Pale Ale        10175
# 151191                                    Pale Ale         5714
# 151409                                HopDevil Ale         1005
# 151964              Brooklyn Black Chocolate Stout          680
# 153962                            Storm King Stout         1013
# 154331                                  Prima Pils         1010
# 156072                              India Pale Ale        25231
# 156115                              Imperial Stout        31365
# 156788                              India Pale Ale         5084
# 157315                               Oatmeal Stout        12891
# 157978                                    Pale Ale        44471
# 157992                              India Pale Ale        35185
#
#                               beer_style  \
# 657              American Pale Ale (APA)
# 975     American Double / Imperial Stout
# 1228             American Pale Ale (APA)
# 1395                       Oatmeal Stout
# 3296    American Double / Imperial Stout
# 4106             American Pale Ale (APA)
# 4148                       Oatmeal Stout
# 6745        English India Pale Ale (IPA)
# 6767             American Pale Ale (APA)
# 7522                        American IPA
# 7552                 American Barleywine
# 7845             American Pale Ale (APA)
# 9106                        American IPA
# 10175       English India Pale Ale (IPA)
# 10944                      Oatmeal Stout
# 11917                      Oatmeal Stout
# 11924                   English Pale Ale
# 12629            American Pale Ale (APA)
# 15408                           Rye Beer
# 15506                       American IPA
# 17408                   English Pale Ale
# 20903                       American IPA
# 21017                      Oatmeal Stout
# 21020                       American IPA
# 21072                       American IPA
# 21118                       American IPA
# 21119             Russian Imperial Stout
# 21253                      Oatmeal Stout
# 23031            American Pale Ale (APA)
# 23531            American Pale Ale (APA)
# ...                                  ...
# 142226      English India Pale Ale (IPA)
# 142227           American Pale Ale (APA)
# 142664                      American IPA
# 142892                      American IPA
# 146458            Russian Imperial Stout
# 146476                  English Pale Ale
# 146477      English India Pale Ale (IPA)
# 146488           American Pale Ale (APA)
# 146511           American Pale Ale (APA)
# 146780                     Oatmeal Stout
# 146782      English India Pale Ale (IPA)
# 146801                      American IPA
# 147631  American Double / Imperial Stout
# 147729                     Oatmeal Stout
# 148873  American Double / Imperial Stout
# 148966           American Pale Ale (APA)
# 149081                  Quadrupel (Quad)
# 150650                      American IPA
# 150655           American Pale Ale (APA)
# 151191           American Pale Ale (APA)
# 151409                      American IPA
# 151964            Russian Imperial Stout
# 153962            Russian Imperial Stout
# 154331                   German Pilsener
# 156072      English India Pale Ale (IPA)
# 156115            Russian Imperial Stout
# 156788      English India Pale Ale (IPA)
# 157315                     Oatmeal Stout
# 157978           American Pale Ale (APA)
# 157992                      American IPA
#
#                                  brewery_name
# 657                           No-Li Brewhouse
# 975                  Founders Brewing Company
# 1228                    Yazoo Brewing Company
# 1395               Mallinsons Brewing Company
# 3296                 Founders Brewing Company
# 4106                  Mountaineer Brewing Co.
# 4148                Tied House Cafe & Brewery
# 6745             Micro-Brasserie L'Alchimiste
# 6767                    Beck's Sports Brewery
# 7522                Sierra Nevada Brewing Co.
# 7552                Sierra Nevada Brewing Co.
# 7845                Sierra Nevada Brewing Co.
# 9106                Sierra Nevada Brewing Co.
# 10175                 Schmohz Brewing Company
# 10944              Four Peaks Brewing Company
# 11917         Rogue's Roost Brew Pub & Eatery
# 11924                        Ginga Kogen Beer
# 12629             Mobjack Bay Brewing Company
# 15408               Bear Republic Brewing Co.
# 15506               Bear Republic Brewing Co.
# 17408                  Long Trail Brewing Co.
# 20903                    Beermann's Beerwerks
# 21017         Mission Springs Brewing Company
# 21020         Mission Springs Brewing Company
# 21072                         Kutztown Tavern
# 21118           Two Rows Restaurant & Brewery
# 21119           Two Rows Restaurant & Brewery
# 21253            District ChopHouse & Brewery
# 23031                     Black Husky Brewing
# 23531                       Dead Frog Brewing
# ...                                       ...
# 142226                Okanagan Spring Brewery
# 142227                Okanagan Spring Brewery
# 142664                     Gore Range Brewery
# 142892               LaConner Brewing Company
# 146458        Gamla Slottskällans Bryggeri AB
# 146476        Gamla Slottskällans Bryggeri AB
# 146477        Gamla Slottskällans Bryggeri AB
# 146488               Yakima Craft Brewing Co.
# 146511             Church-Key Brewing Company
# 146780                 Coddington Brewing Co.
# 146782                 Coddington Brewing Co.
# 146801  Upstream Brewing Company - Old Market
# 147631                     Cervecería El Buho
# 147729          Boundary Bay Brewery & Bistro
# 148873                Pyramid Breweries, Inc.
# 148966                Pyramid Breweries, Inc.
# 149081             Brouwerij St. Bernardus NV
# 150650          Hinterland Brewery Restaurant
# 150655          Hinterland Brewery Restaurant
# 151191               Minocqua Brewing Company
# 151409                Victory Brewing Company
# 151964                       Brooklyn Brewery
# 153962                Victory Brewing Company
# 154331                Victory Brewing Company
# 156072       Meantime Brewing Company Limited
# 156115                                Antares
# 156788                       Big Rock Brewery
# 157315           Copper Creek Brewing Company
# 157978            The Defiant Brewing Company
# 157992            The Defiant Brewing Company
#
# [268 rows x 4 columns]

# %%
from keras.layers import Input, Embedding, Dot, Reshape, Dense
from keras.models import Model,Sequential

# %%
# beer_index = review_df['beer_beerid'].unique()
# user_index = review_df['beer_beerid'].unique()

# %%
# def beer_embedding_model(embedding_size = 50, classification = False):
#     """Model to embed books and wikilinks using the functional API.
#        Trained to discern if a link is present in a article"""
    
#     # Both inputs are 1-dimensional
#     beer = Input(name = 'beer', shape = [1])
#     user = Input(name = 'user', shape = [1])
    
#     # Embedding the book (shape will be (None, 1, 50))
#     beer_embedding = Embedding(name = 'beer_embedding',
#                                input_dim = len(beers_index),
#                                output_dim = embedding_size)(beer)
    
#     # Embedding the link (shape will be (None, 1, 50))
#     user_embedding = Embedding(name = 'user_embedding',
#                                input_dim = len(users_index),
#                                output_dim = embedding_size)(user)
    
#     # Merge the layers with a dot product along the second axis (shape will be (None, 1, 1))
#     merged = Dot(name = 'dot_product', normalize = True, axes = 2)([beer_embedding, user_embedding])
    
#     # Reshape to be a single number (shape will be (None, 1))
#     merged = Reshape(target_shape = [1])(merged)
    
#     # If classifcation, add extra layer and loss function is binary cross entropy
#     if classification:
#         merged = Dense(1, activation = 'sigmoid')(merged)
#         model = Model(inputs = [beer, user], outputs = merged)
#         model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
#     # Otherwise loss function is mean squared error
#     else:
#         model = Model(inputs = [beer, user], outputs = merged)
#         model.compile(optimizer = 'Adam', loss = 'mse')
    
#     return model

# # Instantiate model and show parameters
# model = beer_embedding_model()
# model.summary()
